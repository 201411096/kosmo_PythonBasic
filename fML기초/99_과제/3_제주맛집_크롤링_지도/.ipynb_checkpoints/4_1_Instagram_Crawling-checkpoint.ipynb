# %% [markdown]
# [도서]  [데이터실무분석 with파이썬 예제](https://wikibook.co.kr/playwithdata/)

# %% [markdown]
# # 4.1 인스타그램 크롤링
#
# ### (1) selenium 설치
#
#     + pip install selenium
#
#     + 웹드라이버 다운로드
#         http://chromedriver.chromium.org/downloads
#         chromedirver_win32.zip 파일 다운로드 받고 압축풀기
#
#         설치된 크롬 버전과 맞는 버전을 다운로드 해야 한다.
#
#
# ---
# [참고] 사이트 변경으로 인해 데이타를 못 가져올 수도 있다

# %% [markdown]
# ### 4.1.2 인스타그램 검색 결과 URL을 만들어서 접속하기

# %%
# !pip install selenium

# %%
# 예제 4-1 인스타그램 검색결과 URL을 만드는 함수
def insta_searching(word):
    url = "https://www.instagram.com/explore/tags/" + word
    return url

# %%
webdriverpath = 'D:/python-workspace/PythonBasic/webdriver/chromedriver.exe'

# %% [markdown]
# ### 4.1.3 첫 번째 게시글 열기

# %%
# 예제 4-3 HTML에서 첫번째 게시글 찾아 클릭하기
def select_first(driver):
    
    driver.implicitly_wait(10) # 로딩 속도 때문에 클릭이벤트를 못하기에 추가 ( 상황에 따라 실행되었다 안되었다 함 )
    
    first = driver.find_element_by_css_selector("div._9AhH0")
    first.click()
    time.sleep(3)

# %% [markdown]
# ### 4.1.4 게시글 정보 가져오기

# %%
# 예제 4-4 게시글 정보 가져오기
import re

def get_content(driver):
    # ① 현재 페이지 html 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    # ② 본문 내용 가져오기
    try:
        content = soup.select('div.C4VMK > span')[0].text
    except:
        content = ' '
    # ③ 본문 내용에서 해시태그 가져오기(정규식 활용)
    tags = re.findall(r'#[^\s#,\\]+', content)  
    # ④ 작성일자 정보 가져오기
    date = soup.select('time._1o9PC.Nzb55')[0]['datetime'][:10]
    print('get_content 확인', date)
    # ⑤ 좋아요 수 가져오기
    try:
        like = soup.select('div.Nm9Fw > button')[0].text[4:-1]   
    except:
        like = 0
    # ⑥ 위치정보 가져오기
    try: 
        place = soup.select('div.M30cS')[0].text
    except:
        place = ''
    # ⑦ 수집한 정보 저장하기
    data = [content, date, like, place, tags]
    return data

# %% [markdown]
# ### 4.1.5 다음 게시글 열기

# %%
# 예제 4-5 다음 게시글 열기
def move_next(driver):

    driver.implicitly_wait(10) # 로딩 속도 때문에 클릭이벤트를 못하기에 추가 ( 상황에 따라 실행되었다 안되었다 함 )
    
    right = driver.find_element_by_css_selector ('a.coreSpriteRightPaginationArrow')
    right.click()
    time.sleep(3)

# %% [markdown]
# ### 4.1.6 여러 게시글 정보 수집하기

# %%
import time
#------------------------------------------------------------------------------------
def readp():
    f = open("D:/python-workspace/PythonBasic/webdriver/a.txt")
    a = f.readline()
    return a
def login(driver):
    driver.find_elements_by_css_selector('label.f0n8F > input')[0].send_keys('010-3303-1995')
    driver.find_elements_by_css_selector('label.f0n8F > input')[1].send_keys(readp())
    driver.find_elements_by_css_selector('button.sqdOP > div.Igw0E')[0].click()
    time.sleep(3)
    driver.find_elements_by_css_selector('button.sqdOP')[0].click()

# %%
# 예제 4-6 인스타그램 크롤링
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re

# ① 크롬 브라우저 열기
#driver = webdriver.Chrome('D:/MyClass/Python/eAnalysisExample/2_제주맛집_크롤링_지도/webdriver/chromedriver.exe') 
driver = webdriver.Chrome(webdriverpath)

# ② 인스타그램 검색페이지 URL 만들기
word = "성수핫플"    #검색어
url = insta_searching(word)

# ③ 검색페이지 접속하기
driver.get(url)
time.sleep(3)

# ④ 첫 번째+ 게시글 열기
select_first(driver)
login(driver)
select_first(driver)
# ⑤ 비어있는 변수(results)만들기
results = [ ]


# ⑥→⑦→⑧ 여러 게시물 수집하기
target = 300      # 크롤링할 게시글 수 : 우선은 5개 하고 실제적으로 50개
for i in range(target):
    data = get_content(driver)    # 게시글 정보 가져오기
    results.append(data)
    move_next(driver)
    time.sleep(1)

print(results[:2])
# Out:
# get_content 확인 2020-06-17
# get_content 확인 2020-05-20
# get_content 확인 2020-04-03
# get_content 확인 2020-07-01
# get_content 확인 2020-06-25
# get_content 확인 2020-07-04
# get_content 확인 2020-07-02
# get_content 확인 2020-05-23
# get_content 확인 2020-05-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-07
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-04
# get_content 확인 2020-05-11
# get_content 확인 2019-08-02
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-06
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-04
# get_content 확인 2020-05-21
# get_content 확인 2020-05-19
# get_content 확인 2020-05-16
# get_content 확인 2020-05-11
# get_content 확인 2020-02-18
# get_content 확인 2020-02-07
# get_content 확인 2019-06-11
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-04
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-02
# get_content 확인 2020-07-05
# get_content 확인 2020-07-05
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-06-21
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-02-02
# get_content 확인 2019-12-09
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-04
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-03
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-06-23
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-01
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-02
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# get_content 확인 2020-07-01
# [['🐈🌿파란색 대문을 넘으면 펼쳐지는여름을 쏙 빼닮은 공간-찜통일 줄 알았던 테라스가 의외로 선선해서, 귀여운 침입자들이 자주 걸음 해줘서 더 좋았던 곳 💚,#니콘 #nikonZ50 #daily_nikon', '2020-06-17', '3,664', 'Nontanto', ['#니콘', '#nikonZ50', '#daily_nikon']], ['서울숲 오후 “스테키동”은 하루10그릇, 주말 20그릇 한정 수량 & 모든 메인 메뉴는 재료 소진시 시간과 상관 없이 마감됩니다.출시하자마자 인기 좋은 신메뉴 “차슈정식”도 꼭 드셔보시길 바랍니다:)문 앞 웨이팅 리스트 작성해주시고 현장 대기 해주셔야합니다🙇🏼\u200d♂️오늘도 정성스러운 한 상 준비해 놓을게요. 따뜻한 국과 디저트가지 준비되는 서울숲 오후에서 든든한 식사 하시길 바랍니다:)-코로나 예방으로 손이 닿는 모든 곳은 철저하게 소독제로 소독합니다.문 앞 비치된 손소독제 꼭 사용 부탁드립니다🙏🏻--#서울숲오후#스테키동#서울숲#서울숲맛집#서울숲카페#서울숲핫플#성수동#성수동맛집#성수맛집#성수카페#성수핫플#블루보틀성수#갤러리아포레맛집#갤러리아포레#뚝섬맛집#뚝섬핫플#뚝섬카페', '2020-05-20', '127', '서울숲 오후', ['#서울숲오후', '#스테키동', '#서울숲', '#서울숲맛집', '#서울숲카페', '#서울숲핫플', '#성수동', '#성수동맛집', '#성수맛집', '#성수카페', '#성수핫플', '#블루보틀성수', '#갤러리아포레맛집', '#갤러리아포레', '#뚝섬맛집', '#뚝섬핫플', '#뚝섬카페']]]

# %%
# 예제 4-7 크롤링 결과 저장하기

import pandas as pd



results_df = pd.DataFrame(results)
results_df.columns = ['content','data','like','place','tags']
results_df.to_excel('./files/Instagram_Crawling/4_1_crawling_result.xlsx')

# %% [markdown]
# ### 4.1.8 여러 엑셀 파일의 중복을 제거한 후 통합 저장
#
# 인스타그램에서 여러 개의 키워드로 검색하거나 어러 번에 걸쳐 데이터를 수집하는 경우가 많다.
#
# 동일한 게시물을 중복으로 수집되는 경우 중복을 제거해야 한다.

# %%
# 예제 4-8 여러 개의 저장파일 통합하기
import pandas as pd
insta_crawling_df = pd.DataFrame( [ ] )

folder = './files/Instagram_Crawling/'

# f_list = ['3_1_crawling_jejudoMatJip.xlsx', '3_1_crawling_jejudoGwanGwang.xlsx', '3_1_crawling_jejuMatJip.xlsx', '3_1_crawling_jejuYeoHang.xlsx']
f_list = ['data/4_1_crawling1.xlsx', 'data/4_1_crawling2.xlsx','data/4_1_crawling3.xlsx','4_1_crawling_result.xlsx']

for fname in f_list:
    fpath = folder + fname
    temp = pd.read_excel(fpath, index=False)
    print(temp)
    insta_crawling_df = jeju_insta_df.append(temp)


insta_crawling_df = insta_crawling_df[['content','data','like','place','tags']]
    
insta_crawling_df.columns =['content','data','like','place','tags']

# ???? jeju_insta_df.columns  왜 7개 이지???
# Out:
#      Unnamed: 0                                            content  \
# 0             0                       먹기 너무 아까워🥺#성수카페 #서울숲카페 #묘사서울
# 1             1                                                  💜
# 2             2  저 오랜만이죠🤍인스타를 조금 멀리하고 지낸 몇주간사진 밀렸네용..! 하나씩 올려볼게...
# 3             3                       ⠀퇴근길에 커피나 한잔할까다도 너무 피곤한 #월요일
# 4             4
# ..          ...                                                ...
# 295         295                                             🍏🥑🍐🍋🥝🌿
# 296         296                                                 🍶🎨
# 297         297                                        앞머리 짧아졌지롱 😜
# 298         298  이니셜부터 취향까지 다 똑같은 우리 역시 ...
# 299         299
#
#            data like               place  \
# 0    2020-07-02  340          Myosaㅣ묘사서울
# 1    2020-07-04  291                 성수동
# 2    2020-07-01  194            쎈느 서울 성수
# 3    2020-07-06  221              커피 한 잔
# 4    2020-07-06  682                 NaN
# ..          ...  ...                 ...
# 295  2020-07-06  210             Daejeon
# 296  2020-07-06   79  송리단길 SongniDan-gil
# 297  2020-07-06  143        Seoul, Korea
# 298  2020-07-06   67                 NaN
# 299  2020-07-06   76                 NaN
#
#                                                   tags
# 0                         ['#성수카페', '#서울숲카페', '#묘사서울']
# 1                                                   []
# 2    ['#일상', '#데일리', '#성수동', '#아르코', '#성수카페', '#성수동...
# 3                                             ['#월요일']
# 4                                                   []
# ..                                                 ...
# 295                                                 []
# 296                                                 []
# 297                                                 []
# 298                                                 []
# 299                                                 []
#
# [300 rows x 6 columns]
#      Unnamed: 0                                            content  \
# 0             0  줄 서서 먹는다는 그 유명한 이영자 맛집, 창화당♥바삭하고 속이 꽉 찬 만두부터 새...
# 1             1  .나가서 커피한잔 하면서멍때리면 딱 좋게...
# 2             2  ☁️성수동 골목에서 만난 외국감성 물씬 나ᄃ...
# 3             3  .성수역 2번 출구 근처에 새로생긴 덮밥맛집 #성수핵밥대창덮밥을 드디어 먹어봄♥.♥...
# 4             4  요즘 핫한 데이트 장소 성수동맛집 #럭키페니성수동 카페거리에서 가깝고 가성비가 좋아...
# ..          ...                                                ...
# 295         295       스코니 솔드아웃 ! 마지막 예약손님까지 스콘 마무리했어용❤️ 4판을굽고 또굽고😆
# 296         296  | 공간'S NEW 🛌베드모와 밤부베딩🛌여기서 자ᄆ...
# 297         297                                   photo by 동현 오빠 📸
# 298         298                            오늘 저녁은 뭘먹을까나🎉💃🏻#신나는#금요일
# 299         299  ෆ⃛ ʙᴇᴀᴜᴛʏ ғᴏʀ sᴍɪʟᴇ ෆ⃛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀...
#
#            data   like                  place  \
# 0    2020-06-29      0                    NaN
# 1    2020-06-15  1,525           Seoul, Korea
# 2    2020-07-02  3,382           시몬스 하드웨어 스토어
# 3    2020-06-26      0                    NaN
# 4    2020-06-05      0                    NaN
# ..          ...    ...                    ...
# 295  2020-07-03     13             커피사피엔스 성수점
# 296  2020-07-03     57                 공간 와디즈
# 297  2020-07-03     70      카페 포제 - cafe poze
# 298  2020-07-03    241                    NaN
# 299  2020-07-03    278  뷰티포스마일 Beautyforsmile
#
#                                                   tags
# 0    ['#창화당', '#성수동맛집', '#서울숲맛집', '#성수맛집', '#성수동핫플'...
# 1    ['#로우커피스탠드', '#대한민국구석구석',...
# 2                             ['#a7iii', '#sel2470gm']
# 3    ['#성수핵밥대창덮밥을', '#성수역맛집', '#성수데이트', '#성수동핫플레이스'...
# 4    ['#럭키페니성수동', '#성수동맛집', '#성수동파스타', '#성수동핫플레이스',...
# ..                                                 ...
# 295                                                 []
# 296                                                 []
# 297                                                 []
# 298                                   ['#신나는', '#금요일']
# 299                                                 []
#
# [300 rows x 6 columns]
#      Unnamed: 0                                            content  \
# 0             0  흐아...시원한 콩국수 땡기는날🔥콩국수는 무조...
# 1             1  먹고싶었던 초당옥수수랑 신비복숭아 ᄉ...
# 2             2  서울숲으로 놀러갔다가 배고파서 포맨스 고고띠했지 뭐람🤔❤️ 소스빼고 싹싹 긁어 먹었...
# 3             3  [건대] 압구정곱떡🥘곱창떡볶이 아직도 ...
# 4             4                         올빽☠️#멀태기💇 #머리길이어정쩡
# ..          ...                                                ...
# 295         295  맛집은 역시 한나언니#좋은시간 #열심...
# 296         296  ✅성수 호호식당✅사케도로동과 명란오일파스타개인적으로 혜화에서 먹어봤을때보다 맛나게 ...
# 297         297     해가져도 예쁜 외관이군 💛#성수동와인바 #올드나이브스 #올드나이브스성수 #성수동맛집
# 298         298                                     말할때찍는거아니야...^^
# 299         299  산책후 차에 태울때 물없이 쓱쓱편하고 초코가 발을 안핥는당!!#울지마마이...
#
#            data   like      place  \
# 0    2020-07-03  3,398        성수동
# 1    2020-07-02  1,250        NaN
# 2    2020-07-01  2,681        포맨스
# 3    2020-07-05  1,235        NaN
# 4    2020-07-05    980    Humbolt
# ..          ...    ...        ...
# 295  2020-07-06    786      누메로도스
# 296  2020-07-06     85   성수동 호호식당
# 297  2020-07-06    174  올드나이브스 성수
# 298  2020-07-06    219   성수동 카페거리
# 299  2020-07-06     90        NaN
#
#                                                   tags
# 0       ['#성수동맛집', '#성수맛집', '#조계현칼국수']
# 1                                                   []
# 2                                   ['#포맨스', '#성수동맛집']
# 3    ['#압구정맛집', '#강남맛집', '#수원마...
# 4                            ['#멀태기💇', '#머리길이어정쩡']
# ..                                                 ...
# 295  ['#좋은시간', '#열심히', '#와인🍷', '#누ᄆ...
# 296  ['#호호식당', '#서울숲맛집', '#성수동맛집', '#성수맛집', '#먹스타맞팔...
# 297      ['#성수동와인바', '#올드나이브스', '#올드나이브스성수', '#성수동맛집']
# 298                                                 []
# 299  ['#울지마마이펫', '#dontcrymypet', '#워터리ᄉ...
#
# [300 rows x 6 columns]
#      Unnamed: 0                                            content  \
# 0             0  🐈🌿파란색 대문을 넘으면 펼쳐지는여름으...
# 1             1  서울숲 오후 “스테키동”은 하루10그릇, 주마...
# 2             2  시몬스 침대 브랜드 창립 150주년을 기념해 힙플레이스 성수동에서 시몬스 하드웨어 ...
# 3             3                                 아무생각없이 웃고 떠들었던 하루.
# 4             4  [DA ROBE - 성수]⠀⠀여러 매거진, 그리고 SNS에ᄉ...
# ..          ...                                                ...
# 295         295                          갑자기 추워져 뜨아로😢#오늘도성수
# 296         296  ⛱파라솔이 절대 필요한 공간.#성수아르코 🏝#성수핫플#파라솔@docent_offic...
# 297         297                                나미야 잡화점의 기적이 이로나따 ✨
# 298         298  ㅤㅤㅤㅤㅤ아모레성수에 찾아온 설레는 소식,영...
# 299         299  햇살좋은 서울숲 옆 브런치레스토랑언박스키친의 시즌메뉴 .아보카도 온 토스트🥑🥑유기농...
#
#            data   like           place  \
# 0    2020-06-17  3,664        Nontanto
# 1    2020-05-20    127          서울숲 오후
# 2    2020-04-03  2,787             성수동
# 3    2020-07-01    181  Below Seongsoo
# 4    2020-06-25    505       다로베darobe
# ..          ...    ...             ...
# 295  2020-07-01     12             NaN
# 296  2020-07-01    363             NaN
# 297  2020-07-01     53             NaN
# 298  2020-07-01    183             NaN
# 299  2020-07-01      0             NaN
#
#                                                   tags
# 0              ['#니콘', '#nikonZ50', '#daily_nikon']
# 1    ['#서울숲오후', '#스테키동', '#서울숲', '...
# 2    ['#시몬스', '#시몬스침대', '#시몬스테라스', '#시몬스하드웨어스토어', '...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 295                                  ['#오늘도성수']
# 296       ['#성수아르코', '#성수핫플', '#파라솔@docent_official_']
# 297                                                 []
# 298  ['#아모레성수', '#신제품', '#코덕환영', ...
# 299  ['#성수동맛집', '#언박스키친', '#성수동데이트', '#서울숲데이트', '#성...
#
# [300 rows x 6 columns]
# Index(['content', 'data', 'like', 'place', 'tags', 'Unnamed: 0'], dtype='object')
# 5

# %%
# 예제 4-9 중복 데이터 제거하고 저장하기
insta_crawling_df.drop_duplicates(subset = [ "content"] , inplace = True)
insta_crawling_df.to_excel('./files/Instagram_Crawling/4_1_crawling_raw.xlsx', index = False)
