# %% [markdown]
# #  워드클라우드

# %% [markdown]
# ### 워드 클라우드를 만드는 과정

# %%
# 크롤링 결과 중 해시태그 데이터 불러오기
import pandas as pd
# 통합된 파일 열기
raw_total = pd.read_excel('./files/성수추천.xlsx')
raw_total['tags'] [:3]
# Out:
# 0              ['#니콘', '#nikonZ50', '#daily_nikon']
# 1       ['#성수동맛집', '#성수맛집', '#조계현칼국수']
# 2    ['#cafe', '#cafestagram', '#selfie', '#rooftop...
# Name: tags, dtype: object

# %%
# 해시태그 통합 저장하기
tags_total = []
for tags in raw_total['tags']:
    tags_list = tags[2:-2].split("', '")
    for tag in tags_list:
        tags_total.append(tag)
        
tags_total
# Out:
# ['#니콘',
#  '#nikonZ50',
#  '#daily_nikon',
#  '#성수동맛집',
#  '#성수맛집',
#  '#조계현칼국수',
#  '#cafe',
#  '#cafestagram',
#  '#selfie',
#  '#rooftop',
#  '#ootd',
#  '#lfl',
#  '#selstagram',
#  '#dailylook',
#  '#카페',
#  '#카페스타그램',
#  '#dayoff',
#  '#korean',
#  '#fff',
#  '#맞팔',
#  '#소통',
#  '#얼스타그램',
#  '#셀카',
#  '#인물사진',
#  '#좋반',
#  '#분당',
#  '#일상',
#  '#메롱',
#  '#성수동카페',
#  '#성수동',
#  '#어반소스',
#  '#성수카페',
#  '#서울숲카페',
#  '#묘사서울',
#  '#창화당',
#  '#성수동맛집',
#  '#서울숲맛집',
#  '#성수맛집',
#  '#성수동핫플',
#  '#성수동데이트',
#  '#서울숲데이트',
#  '#성수동',
#  '#성수동핫플레이스',
#  '#성수동카페거리',
#  '#성수동카페',
#  '#성수동맛집추천',
#  '#성수역맛집',
#  '#성수역',
#  '#성수역맛집추천',
#  '#성수맛집추천',
#  '#로우커피스탠드',
#  '#대한민국구석구석',
#  '#사진의언어',
#  '#성수동카페',
#  '#카페투어',
#  '#서울풍경',
#  '#여행스타그램',
#  '#색감미술관',
#  '#사진소통',
#  '#사진찍기좋은곳',
#  '#여행에미치다',
#  '#카페스타그램',
#  '#성수동핫플레이스',
#  '#카페추천',
#  '#wonderful_places',
#  '#korealandscape',
#  '#ig_korea',
#  '#koreanearandfar',
#  '#ig_seoul',
#  '#seoultravel',
#  '#visitkorea',
#  '#manmakecoffee',
#  '#beautifuldestinations',
#  '#koreabyme',
#  '#welivetoexplore',
#  '#justgoshoot',
#  '#bestvacations',
#  '#seoul_korea',
#  '#somewheremagazine',
#  '#x100v',
#  '',
#  '',
#  '',
#  '#서울숲오후',
#  '#스테키동',
#  '#서울숲',
#  '#서울숲맛집',
#  '#서울숲카페',
#  '#서울숲핫플',
#  '#성수동',
#  '#성수동맛집',
#  '#성수맛집',
#  '#성수카페',
#  '#성수핫플',
#  '#블루보틀성수',
#  '#갤러리아포레맛집',
#  '#갤러리아포레',
#  '#뚝섬맛집',
#  '#뚝섬핫플',
#  '#뚝섬카페',
#  '#a7iii',
#  '#sel2470gm',
#  '#시몬스',
#  '#시몬스침대',
#  '#시몬스테라스',
#  '#시몬스하드웨어스토어',
#  '#simmonshardwarestore',
#  '#포맨스',
#  '#성수동맛집',
#  '',
#  '#일상',
#  '#데일리',
#  '#성수동',
#  '#아르코',
#  '#성수카페',
#  '#성수동카페',
#  '#데일리룩',
#  '#셀카',
#  '#얼스타그램',
#  '#새댁',
#  '#신혼부부',
#  '#예신',
#  '#daily',
#  '#ootd',
#  '#압구정맛집',
#  '#강남맛집',
#  '#수원맛집',
#  '#건대맛집',
#  '#부평맛집',
#  '#건대맛집',
#  '#압구정곱떡',
#  '#무드_건대',
#  '#셀스타그램',
#  '#얼스타그램',
#  '#셀스타',
#  '#셀피',
#  '#데일리룩',
#  '#데일리코디',
#  '#코디',
#  '#패션',
#  '#남자모델',
#  '#피팅모델',
#  '#패션모델',
#  '#촬영문의',
#  '#kfashion',
#  '#fashion',
#  '#koreafashion',
#  '#koreanstyle',
#  '#kstyle',
#  '#koreanmodel',
#  '#korean',
#  '#좋반',
#  '#오오티디',
#  '#좋아요반사',
#  '#데일리',
#  '#인친',
#  '#팔로우',
#  '#일상',
#  '#95',
#  '#성수',
#  '#성수동카페거리',
#  '#성수동',
#  '#cafestagram',
#  '#selfie',
#  '#rooftop',
#  '#ootd',
#  '#lfl',
#  '#selstagram',
#  '#dailylook',
#  '#카페',
#  '#카페스타그램',
#  '#dayoff',
#  '#korean',
#  '#fff',
#  '#맞팔',
#  '#소통',
#  '#얼스타그램',
#  '#좋반',
#  '#셀카',
#  '#루프탑카페',
#  '#분당',
#  '#일상',
#  '#성수동카페',
#  '#성수동',
#  '#어반소스',
#  '#월요일',
#  '',
#  '#성수핵밥대창덮밥을',
#  '#성수역맛집',
#  '#성수데이트',
#  '#성수동핫플레이스',
#  '#성수동밥집',
#  '#성수덮밥',
#  '#대창덮밥',
#  '#성수역맛집추천',
#  '#성수동맛집추천',
#  '#성수어니언',
#  '#멀태기💇',
#  '#머리길이어정쩡',
#  '',
#  '',
#  '#럭키페니성수동',
#  '#성수동맛집',
#  '#성수동파스타',
#  '#성수동핫플레이스',
#  '#성수동핫플',
#  '#성수동데이트',
#  '#성수맛집',
#  '#성수파스타',
#  '#성수데이트',
#  '#성수역맛집',
#  '#성수동카페거리',
#  '#플디',
#  '#뚝섬..플디의',
#  '',
#  '',
#  '#bbhay',
#  '#비비해이-@j__w.n',
#  '',
#  '#꿀주말',
#  '',
#  '',
#  '#비누자격증',
#  '#창업반',
#  '#공드리워크샵',
#  '#성수동공방',
#  '#성수동',
#  '#천연비누',
#  '#cpsoap',
#  '#비누자격증',
#  '#솝마스터',
#  '#비누만들기',
#  '#비누공방',
#  '#성수동핫플레이스',
#  '#성수',
#  '#건대공방',
#  '#디자인비누',
#  '#명화비누',
#  '#coldprocesssoap',
#  '#비누',
#  '#일상',
#  '#맞팔',
#  '#선팔',
#  '#비누공방',
#  '#창업',
#  '#직장인',
#  '#직장인취미',
#  '',
#  '#묘사서울',
#  '#myosaseoul',
#  '#ndd',
#  '#yami_성수',
#  '#성수동카페',
#  '#성수카페',
#  '#냐냐_냠냠',
#  '#냐냐_다이어트⠀200523',
#  '#스무디볼',
#  '#신사동카페',
#  '#논탄토',
#  '#coffee',
#  '',
#  '',
#  '#목요팅',
#  '#목요일',
#  '#출근중',
#  '#연무장',
#  '#성수핫플',
#  '#성수동핫플',
#  '#루프탑카페',
#  '#날씨좋아',
#  '#여름날씨',
#  '#반팔',
#  '#반바지',
#  '#츄리닝',
#  '#출근룩',
#  '#강남역',
#  '#건대입구',
#  '#서울숲',
#  '#한남동',
#  '#주말뭐하지',
#  '#seoul',
#  '#나들이',
#  '#일개미',
#  '#소통스타그램',
#  '#댓글소통',
#  '#앤드밀',
#  '#브런치카페',
#  '#카페그램',
#  '',
#  '#성수동카페',
#  '#성수카페',
#  '#성수',
#  '#뚝섬카페',
#  '#뚝섬역카페',
#  '#무드랩',
#  '#그리고일렉텐이랑한강',
#  '#💕',
#  '#연남동파스타',
#  '#연트럴파크맛집',
#  '#오스테리아레스또',
#  '#연남동맛집',
#  '#연남맛집',
#  '#연트럴파크',
#  '#연남동맛집추천',
#  '#연남동데이트',
#  '#연남동핫플',
#  '#연남동와인',
#  '#연남동파스타맛집',
#  '#연남동가볼만한곳',
#  '#좋반',
#  '#좋아요반사',
#  '#좋아요',
#  '#좋반테러',
#  '#강남역맛집',
#  '#성수동맛집',
#  '',
#  '#성수동',
#  '#로스터리',
#  '#디카페인',
#  '#성수동모시깽이',
#  '#피어커피by',
#  '#솦깽이',
#  '#mmapc',
#  '#메가네이트',
#  '#meganate',
#  '#armin',
#  '#성수역',
#  '#성수동',
#  '#성수동핫플레이스',
#  '#성수동핫플',
#  '#서울숲',
#  '#핸드메이드',
#  '#핸드메이드가방',
#  '#데일리룩',
#  '#데일리코디',
#  '#인스타데일리',
#  '#성수동데이트',
#  '#성수동공방',
#  '#클러치추천',
#  '#여자친구선물',
#  '#남자친구선물',
#  '#셔츠',
#  '#파우치',
#  '#클러치',
#  '#클러치백',
#  '#가방추천',
#  '#뚝섬역',
#  '#인스타데일리',
#  '#ootd',
#  '#dailylook',
#  '#아이폰케이스',
#  '#폰케이스',
#  '#명품케이스',
#  '#커플케이스',
#  '#아이폰',
#  '#갤럭시케이',
#  '#디젤매니아',
#  '#디매',
#  '#나매인',
#  '#피마원',
#  '#피마원케이스',
#  '#새폰',
#  '#새폰장만',
#  '#새폰케이스',
#  '#아이폰11',
#  '#강남네일',
#  '#강남네일샵',
#  '#봄네일',
#  '#s20케이스',
#  '#노트10케이스',
#  '#홍대맛집',
#  '#한남동맛집',
#  '#합정맛집',
#  '#성수동맛집',
#  '#청담맛집',
#  '#여친선물',
#  '#남친선물',
#  '#구찌케이스',
#  '#제주맛집',
#  '#고야드케이스',
#  '',
#  '#폴라앳홈스토어',
#  '#다기셋트',
#  '#감사합니다',
#  '#폴라앳홈스토어',
#  '#성수동편집샵',
#  '#성수동핫플',
#  '#성수동핫플레이스',
#  '#성수동리빙숍',
#  '#폴라앳홈',
#  '#그릇쇼핑',
#  '#그릇덕후',
#  '#그릇가게',
#  '#성수동그릇가게',
#  '',
#  '#성수',
#  '#성수동',
#  '#성수카페거리',
#  '#한강나들이',
#  '#뚝섬',
#  '#성수동카페',
#  '#바다',
#  '#일상',
#  '#2020년',
#  '#2020',
#  '#서울',
#  '#데이트',
#  '#드라마',
#  '#성수동맛집',
#  '#건대',
#  '#먹스타그램',
#  '#사랑',
#  '#고마워요💕',
#  '#2월14일',
#  '#선물',
#  '#성수카페',
#  '#일상',
#  '#일상그램',
#  '#좋아요',
#  '#좋아요반사',
#  '#홍대',
#  '#오오티디룩',
#  '#오오티디',
#  '#맞팔',
#  '#선팔',
#  '#맞팔하면선팔',
#  '#로미새',
#  '#브런치',
#  '#성수동',
#  '#성수동카페',
#  '#서울무채색카페',
#  '#무채색카페',
#  '#색감카페',
#  '#흑백카페',
#  '#성수카페',
#  '#성수동카페',
#  '#성수핫플',
#  '#성수데이트',
#  '#성수동핫플',
#  '#성수동데이트',
#  '#성수',
#  '#성수동',
#  '#성수카페거리',
#  '#한강나들이',
#  '#뚝섬',
#  '#성수동카페',
#  '#바다',
#  '#일상',
#  '#2020년',
#  '#2020',
#  '#서울',
#  '#데이트',
#  '#드라마',
#  '#성수동맛집',
#  '#건대',
#  '#먹스타그램',
#  '#사랑',
#  '#고마워요💕',
#  '#2월14일',
#  '#선물',
#  '#성수카페',
#  '#일상',
#  '#일상그램',
#  '#좋아요',
#  '#좋아요반사',
#  '#홍대',
#  '#오오티디룩',
#  '#오오티디',
#  '#맞팔',
#  '#선팔',
#  '#맞팔하면선팔',
#  '',
#  '',
#  '',
#  '#리그램',
#  '#여러분이',
#  '#칙피스성수점',
#  '#pre-open',
#  '#소박하지만',
#  '#성수점도',
#  '#아트놈작가',
#  '#서울',
#  '#출연',
#  '#위원준셰프',
#  '#지하4층까지',
#  '#성수동맛집',
#  '#성수동샐러드',
#  '#성수동핫플레이스',
#  '#성수동카페',
#  '#성수카페',
#  '#chickpeace',
#  '#칙피스',
#  '#샐러드맛집',
#  '#브런치카페',
#  '#성수동칙피스',
#  '#index',
#  '#indexcaramel',
#  '#수제카라멜',
#  '#생카라멜',
#  '#화요일',
#  '#칼퇴성공',
#  '',
#  '#에르메스',
#  '#오란슬리퍼',
#  '#헤이보울',
#  '#카페',
#  '#카페추천',
#  '#신상메뉴',
#  '#콜라보메뉴',
#  '#뚝섬카페',
#  '#coffee',
#  '#성수카페',
#  '#감성카페',
#  '#seoul',
#  '#seoulcafe',
#  '#cafe',
#  '#selfie',
#  '#instagram',
#  '#신상카페',
#  '#건강식카페',
#  '#스노우볼',
#  '#라즈베리바질',
#  '#옐로우',
#  '#퍼플',
#  '#그린',
#  '#그래놀라',
#  '#성수동',
#  '#성수헤이보울',
#  '#에젤커피',
#  '#성수동카페',
#  '#성수동맛집',
#  '#로투스스무디',
#  '#오렌지에이드',
#  '#에젤슈페너',
#  '#아메리카노',
#  '#티라미수롤',
#  '#송정스콘',
#  '#스콘',
#  '#초코스콘',
#  '#송정커피',
#  '#송정커피',
#  '#성동구송정동',
#  '#송정동뚝방길',
#  '#화양사거리카페',
#  '#화양사거리',
#  '#송정동카페',
#  '#송정동뚝방길카페',
#  '#세종대학교',
#  '#세종대',
#  '#건대입구',
#  '#건국대학교',
#  '#화양동카페',
#  '#송정동단풍',
#  '#어린이대공원',
#  '#군자역',
#  '#군자역카페',
#  '#어린이대공원역맛집',
#  '#송정동',
#  '#성동구송정동',
#  '#송정동뚝방길',
#  '#세종대학교',
#  '#건국대학교',
#  '#화양동카페',
#  '#송정동카페',
#  '#성동구송정동카페',
#  '#송정커피',
#  '#송정동카페',
#  '#성동구송정동',
#  '#송정동뚝방길',
#  '#성수동카페',
#  '#화양동카페',
#  '#화양사거리',
#  '#군자역',
#  '#군자카페',
#  '#송정동뚝방길',
#  '#세종대학교',
#  '#세종대카페',
#  '#어린이대공원카페',
#  '#어린이대공원역',
#  '#건국대학교',
#  '#건대입구',
#  '#군자카페',
#  '#성수동',
#  '#성수동카페',
#  '#성수동핫플',
#  '#송정길',
#  '#백수라이프',
#  '#공방데이트',
#  '#수국',
#  '#여름',
#  '#성수동카페',
#  '#성수동카페거리',
#  '#성수동',
#  '#카페스타그램',
#  '#카페투어',
#  '#셀스타그램',
#  '#둔산동',
#  '#봉명동',
#  '#도안동',
#  '#일상',
#  '#일상스타그램',
#  '#셀피',
#  '#데일리',
#  '#좋아요',
#  '#맞팔',
#  '#팔로우',
#  '#coffee',
#  '#daily',
#  '#dailygram',
#  '#cafe',
#  '#cafestagram',
#  '#travel',
#  '#travelgram',
#  '#f4f',
#  '#following',
#  '',
#  '#🍦엄마',
#  '#성수동',
#  '#성수동핫플레이스',
#  '#5살아들',
#  '#일상기록',
#  '#성수동맛집',
#  '#성수동샐러드',
#  '#샐러드',
#  '#샐러드맛집',
#  '#instastyle',
#  '#instagood',
#  '#salad',
#  '#foodstagram',
#  '',
#  '#구욱희씨',
#  '#성수',
#  '#서울숲',
#  '#뚝섬',
#  '#성수동카페',
#  '#성수맛집',
#  '#성수동쿠키',
#  '#서울숲주차장',
#  '#서울신상카페',
#  '#성수동핫플레이스',
#  '#카페투어',
#  '#감성사진',
#  '#사진스타그램',
#  '#카페스타그램',
#  '',
#  '#일상을여행처럼린다G',
#  '#바이산..',
#  '#성수핫플',
#  '#놀면뭐하니',
#  '#서울여행지',
#  '#바이산대림창고',
#  '#놀면뭐하니촬영장소',
#  '#성수카페',
#  '#혲_성수',
#  '#20200705',
#  '#supermatcha',
#  '',
#  '',
#  '#ASH1부(20:30-21:15)',
#  '#한남동맛집',
#  '#황금동맛집',
#  '#불로동맛집',
#  '#삼성동맛집',
#  '#해운대술집',
#  '#여수맛집',
#  '#서울숲맛집',
#  '#수입보세',
#  '#해운대맛집',
#  '#동래맛집',
#  '#센텀맛집',
#  '#도산공원맛집',
#  '#수성못맛집',
#  '#센텀신세계',
#  '#대구신세계',
#  '#소공동롯데',
#  '#시그니엘부산',
#  '#파라다이스호텔',
#  '#해운대맛집',
#  '#파크하얏트부산',
#  '#신세계본점',
#  '#삼산동맛집',
#  '#성수동맛집',
#  '#대구맛집',
#  '#서울신라호텔',
#  '#홍콩수입의류',
#  '#하남맛집',
#  '#도산공원브런치⠀',
#  '#로라일상',
#  '#아모레성수...',
#  '#메종드로지',
#  '#성수동캔들공방',
#  '#공방라이프',
#  '#뒷이야기는생략하겠습니다',
#  '#럽스타그램',
#  '#티파인효소공구오늘',
#  '#티파인효소공구는앨리마켓',
#  '#브릭캠퍼스',
#  '#브캉스',
#  '#성수핫플',
#  '#서울숲전시',
#  '#서울',
#  '#성수동카페',
#  '#arco',
#  '',
#  '',
#  '',
#  '#셀카',
#  '#셀피',
#  '#좋아요',
#  '#셀스타그램',
#  '#팔로미',
#  '#인스타그램',
#  '#일상',
#  '#데일리',
#  '#소통',
#  '#팔로우',
#  '#울산',
#  '#삼산',
#  '#서울',
#  '#부산',
#  '#선팔',
#  '#맞팔',
#  '#인스타',
#  '#좋반',
#  '#좋아요반사',
#  '#instadaily',
#  '#selca',
#  '#selfie',
#  '#selstagram',
#  '#instagram',
#  '#follow',
#  '#instagood',
#  '#f4f',
#  '#ootd',
#  '#daily',
#  '#성수카페',
#  '#아모레성수',
#  '#헤라',
#  '#쿠션추천',
#  '#AMOREseongsu',
#  '#HERA',
#  '#recommendcushion',
#  '#jmt',
#  '#성수동맛집',
#  '#murmursroom',
#  '#illustrator',
#  '#illust',
#  '#캘리그라피',
#  '#캘스타그램',
#  '#케이스',
#  '#케이스추천',
#  '#일러스트레이터',
#  '#소품샵',
#  '#소품샵투어',
#  '#좋아요반사',
#  '#선물추천',
#  '#레터링케이스',
#  '#레터링',
#  '#글스타그램',
#  '#키링추천',
#  '#아이폰케이스',
#  '#갤럭시케이스',
#  '#아이폰7케이스',
#  '#아이폰8케이스',
#  '#아이폰xs케이스',
#  '#아이폰x케이스',
#  '#아이폰11',
#  '#아이폰11프로',
#  '#아이폰11케이스',
#  '#아이폰11프로케이스',
#  '#커플케이스',
#  '#하드케이스',
#  '#젤리케이스',
#  '#성수동카페',
#  '',
#  '',
#  '#키메네상점',
#  '',
#  '#닥스훈트',
#  '#애견운동장',
#  '#강아지그램',
#  '#네이처독',
#  '#신메뉴출시',
#  '#품평',
#  '#디저트맛집',
#  '#성수동핫플레이스',
#  '#dutchbaby',
#  '#fruitdessert',
#  '#맛집추천',
#  '#요기니라이프',
#  '#요기니푸드',
#  '#yoginifood',
#  '#무드랩',
#  '#성수',
#  '#청주한씨',
#  '#알콜소비촉진위원회',
#  '#닭은치킨이지',
#  '#양념반후라이드반',
#  '#그래도여름엔',
#  '#치킨대신',
#  '#성수동청주한씨',
#  '#한식오마카세',
#  '#성수맛집',
#  '#성수술집',
#  '#성수핫플',
#  '#한경희셰프',
#  '#한식주점',
#  '#여름보양식',
#  '#트러플리조또',
#  '',
#  '#이달의아트',
#  '#네일이벤트',
#  '#네일아트무제한',
#  '#스톤네일',
#  '#유행네일',
#  '#여름네일',
#  '#여름이벤트.감각적인',
#  '#젤네일잘하는곳',
#  '#탐라네일.👫2인동시',
#  '',
#  '#성수동카페거리',
#  '#대림창고',
#  '#예쁜카페☕️',
#  '#분위기깡패',
#  '#라떼마끼아또☕️',
#  '#루이보스',
#  '#일상기록📷',
#  '',
#  '#Doros',
#  '#도로스',
#  '#ssfashion',
#  '#ootd',
#  '#daily',
#  '#instalike',
#  '#selfie',
#  '#fashion',
#  '#bag',
#  '#summerbag',
#  '#followforfollowback',
#  '#model',
#  '#👜',
#  '#studio',
#  '#맞팔',
#  '#좋반',
#  '#여름신상',
#  '#신상가방',
#  '#여름패션',
#  '#20대쇼핑몰',
#  '#30대쇼핑몰',
#  '#데일리룩',
#  '#데일리코디',
#  '#성수동카페',
#  '#바캉스룩',
#  '#젤리슈즈',
#  '#여름신발',
#  '#토트백',
#  '#성수핫플',
#  '#신상업뎃',
#  '#샘플팩토리',
#  '#화요일',
#  '',
#  '#트로피컬라즈드블루>',
#  '#씨제이로블루',
#  '#cjroblue',
#  '#tropicalizedblue',
#  '#트로피컬라이즈드블루',
#  '#알비arby',
#  '#알비',
#  '#arby',
#  '#그림선물',
#  '#선물',
#  '#굿즈',
#  '#빈티지엽서',
#  '#미니포스터',
#  '#빈티지포스터',
#  '#빈티지포스터카페',
#  '#arby',
#  '#카페알비',
#  '#성수동',
#  '#서울숲',
#  '#서울숲카페',
#  '#서점',
#  '#북카페',
#  '#포스터샵',
#  '#poster',
#  '#성수동카페',
#  '#전시',
#  '#갤러리',
#  '#대관',
#  '#협업전시',
#  '#아티스트',
#  '#Doros',
#  '#도로스',
#  '#ssfashion',
#  '#ootd',
#  '#daily',
#  '#instalike',
#  '#selfie',
#  '#fashion',
#  '#bag',
#  '#summerbag',
#  '#followforfollowback',
#  '#model',
#  '#👜',
#  '#studio',
#  '#맞팔',
#  '#좋반',
#  '#여름신상',
#  '#신상가방',
#  '#여름패션',
#  '#20대쇼핑몰',
#  '#30대쇼핑몰',
#  '#데일리룩',
#  '#데일리코디',
#  '#성수동카페',
#  '#바캉스룩',
#  '#젤리슈즈',
#  '#여름신발',
#  '#토트백',
#  '#성수핫플',
#  '#여름가방',
#  '#바이산',
#  '#바이산카페',
#  '#성수동카페',
#  '#바이산코리아',
#  '#테라스',
#  '#성수동핫플레이스',
#  '#페페로니피자',
#  '#파스타',
#  '#맛점',
#  '#일상',
#  '#데일리',
#  '#데일리룩',
#  '#오오티디',
#  '#어제',
#  '#수다',
#  '#좋아요',
#  '#굿',
#  '#달고나밀크티',
#  '#카페차😋😋역시',
#  '#달고나',
#  '#cafecha',
#  '#달고나화차밀크티',
#  '#달고나아쌈밀크티',
#  '#성수카페',
#  '#Doros',
#  '#도로스',
#  '#ssfashion',
#  '#ootd',
#  '#daily',
#  '#instalike',
#  '#selfie',
#  '#fashion',
#  '#bag',
#  '#summerbag',
#  '#followforfollowback',
#  '#model',
#  '#👜',
#  '#studio',
#  '#맞팔',
#  '#좋반',
#  '#여름신상',
#  '#신상가방',
#  '#여름패션',
#  '#20대쇼핑몰',
#  '#30대쇼핑몰',
#  '#데일리룩',
#  '#데일리코디',
#  '#성수동카페',
#  '#바캉스룩',
#  '#젤리슈즈',
#  '#여름신발',
#  '#토트백',
#  '#성수핫플',
#  '#마크라메가방',
#  '',
#  '#Doros',
#  '#도로스',
#  '#macrame',
#  '#ootd',
#  '#daily',
#  '#instalike',
#  '#selfie',
#  '#fashion',
#  '#bag',
#  '#summerbag',
#  '#followforfollowback',
#  '#model',
#  '#👜',
#  '#studio',
#  '#맞팔',
#  '#좋반',
#  '#여름신상',
#  '#신상가방',
#  '#여름패션',
#  '#20대가방',
#  '#30대가방',
#  '#데일리룩',
#  '#데일리코디',
#  '#성수동카페',
#  ...]

# %%
# 좋아요(like)컬럼 많은순으로 정렬하기
raw_total=raw_total.sort_values(by='like', ascending=False)
raw_total.head(10)
# Out:
#       index                                            content        data  \
# 34        7  보고싶은 내동생 주찬이의 원픽💙🦋 ...이트...  2020-06-29
# 0         0  🐈🌿파란색 대문을 넘으면 펼쳐지는여름으...  2020-06-17
# 1         0  흐아...시원한 콩국수 땡기는날🔥콩국수는 무조...  2020-07-03
# 10        2  ☁️성수동 골목에서 만난 외국감성 물씬 나ᄃ...  2020-07-02
# 40        8                         성수는 옷맛집이라해서 입어봤는데 너무 크다🤪❤️  2020-07-04
# 11        2  시몬스 침대 브랜드 창립 150주년을 기념해 힙플레이스 성수동에서 시몬스 하드웨어 ...  2020-04-03
# 12        2  서울숲으로 놀러갔다가 배고파서 포맨스 고고띠했지 뭐람🤔❤️ 소스빼고 싹싹 긁어 먹었...  2020-07-01
# 1618    462  .친구들하고 서울숲 갔다가성수동맛집이라고해서 여음 갈려는데 웨이팅이...ㄷㄷ결국엔 ...  2020-06-26
# 261      56  <정품 폴로랄프로렌 반팔티 공구>공구는 합리적이고 양심적인 제품을 저렴하게 구매해야...  2020-07-07
# 5         1  .나가서 커피한잔 하면서멍때리면 딱 좋게...  2020-06-15
#
#       like         place                                               tags
# 34    4215           연무장                                                 []
# 0     3664      Nontanto            ['#니콘', '#nikonZ50', '#daily_nikon']
# 1     3398           성수동     ['#성수동맛집', '#성수맛집', '#조계현칼국수']
# 10    3382  시몬스 하드웨어 스토어                           ['#a7iii', '#sel2470gm']
# 40    3033           성수동                                                 []
# 11    2787           성수동  ['#시몬스', '#시몬스침대', '#시몬스테라스', '#시몬스하드웨어스토어', '...
# 12    2681           포맨스                                 ['#포맨스', '#성수동맛집']
# 1618  2202           NaN  ['#성수동맛집', '#성수맛집', '#성수동핫플레이스', '#성수동핫플', '#서...
# 261   2082           연무장                                                 []
# 5     1525  Seoul, Korea  ['#로우커피스탠드', '#대한민국구석구석',...

# %% [markdown]
# ### 막대차트로 좋아요(like) 순위 살펴보기

# %%
#시각화 라이브러리 호출 및 환경 설정(한글 폰트)
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import sys

if sys.platform in ["win32", "win64"]:
    font_name = "malgun gothic"
elif sys.platform == "darwin":
    font_name = "AppleGothic"

rc('font',family=font_name)

# %%
# 데이터 준비하기
# 보여줄 데이터만 출력
df=raw_total[['like','place']]
# 결측치 제거
df=df.dropna(axis=0)
df=df.head(15)
df
# Out:
#       like          place
# 34    4215            연무장
# 0     3664       Nontanto
# 1     3398            성수동
# 10    3382   시몬스 하드웨어 스토어
# 40    3033            성수동
# 11    2787            성수동
# 12    2681            포맨스
# 261   2082            연무장
# 5     1525   Seoul, Korea
# 35    1312     Myosaㅣ묘사서울
# 1180  1198  헤이보울 hey.bowl
# 1337  1022            뚝섬역
# 1374  1000      Arco  아르코
# 21     980        Humbolt
# 16     955             성수

# %%
# 막대 차트 그리기
plt.figure(figsize=(24,8)) 
plt.bar(df['place'], df['like']);
plt.ylabel("LIKE")
plt.xlabel("PLACE")
# Out:
# Text(0.5, 0, 'PLACE')

# %% [markdown]
# ### 워드 클라우드 그리기

# %%
# 예제 4-14 데이터 정제하기
STOPWORDS = ['#일상', '#선팔', '#광고']

total_selected = []
for tag in tags_total:
    if tag not in STOPWORDS:
        total_selected.append(tag)
        
counts_selected = Counter(total_selected)
counts_selected.most_common(10)
# Out:
# [('', 641),
#  ('#성수동카페거리', 196),
#  ('#성수동카페', 186),
#  ('#성수동맛집', 155),
#  ('#성수동', 152),
#  ('#성수동핫플레이스', 131),
#  ('#성수동카페', 112),
#  ('#성수카페', 100),
#  ('#성수핫플', 87),
#  ('#성수', 82)]

# %%
#워드클라우드 라이브러리 불러오기
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import platform

if platform.system() == 'Windows':   #윈도우의 경우
    font_path = "c:/Windows/Fonts/malgun.ttf"
elif platform.system() == "Darwin":   #Mac 의 경우
    font_path = "/Users/$USER/Library/Fonts/AppleGothic.ttf"

# %%
#워드클라우드 만들기
wordcloud=WordCloud(font_path= font_path, 
                    background_color="white",
                    max_words=50,
                    relative_scaling= 0.3,
                    width = 800,
                    height = 400
                 ).generate_from_frequencies(counts_selected)  
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('./files/sungsu.png')  # 저장할경로
