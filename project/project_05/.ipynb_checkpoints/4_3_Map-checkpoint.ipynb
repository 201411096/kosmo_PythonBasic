# %% [markdown]
# #### 카카오 API  #####
#
# - 안내 페이지: http://bit.ly/pwd_kakaoAPI_guide
# - 깃헙 주소: https://github.com/Play-with-data/datasalon

# %%
# folium 설치

#! pip install folium

# %% [markdown]
# # 지도시각화

# %% [markdown]
# ###   데이터 준비

# %%
# 크롤링 데이터 불러오기
import pandas as pd
raw_total = pd.read_excel('./files/성수추천.xlsx')
raw_total.head()
raw_total=raw_total.dropna(axis=0)
raw_total
# Out:
#       index                                            content        data  \
# 1         1  .나가서 커피한잔 하면서멍때리면 딱 좋게...  2020-06-15
# 2         2  ☁️성수동 골목에서 만난 외국감성 물씬 나ᄃ...  2020-07-02
# 5         5  ⠀보기만해도 시끌시끌한 유빈이네 주말도 끝 ...  2020-07-06
# 7         7  보고싶은 내동생 주찬이의 원픽💙🦋 ...이트...  2020-06-29
# 8         8         부지런히 살면 언젠가 보상을 받는다게으름을 피우면 당장 확실한 보상을 받는다  2020-07-06
# ...     ...                                                ...         ...
# 1744    579  오랜만이야❤....................#사진스타그램 #럽스타그램 #럽스타 ...  2020-06-23
# 1745    580  ⠀-#데일리룩#셀피..사진잘찍네요 요실장님?#사진고자 세요?😨2page보고 반성하세...  2020-06-23
# 1747    582  #성수동카페거리 #헤이보울🥗#한끼식사👍로 충분한 요거트.🍧#Smoothie bowl...  2020-06-23
# 1748    583  매력있는 성수동~~❣️요즘같은 날씨에 루프탑이 짱이지👍🏻 #성수동카페 #성수동 #어...  2020-06-23
# 1749    584  #커피스타그램--샌프란시스코여행중 매번 ᄀ...  2020-06-23
#
#        like                place  \
# 1     1,525         Seoul, Korea
# 2     3,382         시몬스 하드웨어 스토어
# 5       314                   진해
# 7     4,215                  연무장
# 8       254                대림 창고
# ...     ...                  ...
# 1744    118        헤이보울 hey.bowl
# 1745    594              메가박스 성수
# 1747      9        헤이보울 hey.bowl
# 1748    121           Cafe Onion
# 1749    112  블루보틀 Blue Bottle 성수
#
#                                                    tags
# 1     ['#로우커피스탠드', '#대한민국구석구석',...
# 2                              ['#a7iii', '#sel2470gm']
# 5                                                    []
# 7                                                    []
# 8                                                    []
# ...                                                 ...
# 1744  ['#사진스타그램', '#럽스타그램', '#럽스타', '#커플스타그램', '#데이트...
# 1745  ['#데일리룩', '#셀피..사진잘찍네요', '#사진고자', '#아이디헤어', '#...
# 1747  ['#성수동카페거리', '#헤이보울🥗', '#한끼식사👍로', '#Smoothie',...
# 1748  ['#성수동카페', '#성수동', '#어니언카페', '#성수동카페거리', '#맘에들...
# 1749  ['#커피스타그램--샌프란시스코여행중', '#ᄇ...
#
# [1094 rows x 6 columns]

# %%
#위치정보 가져오기
location_counts = raw_total['place'].value_counts( )
location_counts
# Out:
# 성수동                      54
# Arco  아르코                38
# 할아버지공장                   34
# Seoul, Korea             30
# 서울숲 Seoul Forest Park    26
#                          ..
# 연남동 어딘가                   1
# 카페라니_cafe rani            1
# 동대문디자인플라자 DDP             1
# Affair Coffee 어페어 커피      1
# 랑데자뷰 건대                   1
# Name: place, Length: 346, dtype: int64

# %%
# 등록된 위치정보별 빈도수 데이터
location_counts_df = pd.DataFrame(location_counts)
location_counts_df.head()
# Out:
#                        place
# 성수동                       54
# Arco  아르코                 38
# 할아버지공장                    34
# Seoul, Korea              30
# 서울숲 Seoul Forest Park     26

# %%
#위치정보 빈도수 데이터 저장하기
location_counts_df.to_excel('./files/성수추천count.xlsx')

# %%
#위치정보 종류 확인하기
locations = list( location_counts.index )
locations
# Out:
# ['성수동',
#  'Arco  아르코',
#  '할아버지공장',
#  'Seoul, Korea',
#  '서울숲 Seoul Forest Park',
#  '연무장',
#  '성수동 성수2가',
#  'ᴅʏᴜʟ ᴄᴏғғᴇᴇ 디열커피',
#  '옹근달',
#  '헤이보울 hey.bowl',
#  '성수동 어딘가',
#  'KANTO CAFE',
#  '블루보틀 Blue Bottle 성수',
#  '대림 창고',
#  '성수동 카페거리',
#  '성수',
#  '성수연방',
#  '공간 와디즈',
#  '우란문화재단',
#  '빅토리아 베이커리',
#  '세라성수점',
#  '성수동근처',
#  'Cafe Onion',
#  '카페 포제 - cafe poze',
#  '뷰티포스마일 Beautyforsmile',
#  'BNHR',
#  '서울숲',
#  'BBHAY',
#  '성수동 어반소스',
#  '메가박스 성수',
#  'ㅊa',
#  '이태리차차',
#  '성수동 어니언',
#  '성수다락',
#  '커피사피엔스 성수점',
#  '시몬스 하드웨어 스토어',
#  'cociety',
#  '유어네임히얼',
#  '아모레성수',
#  'SCENE SEOUL',
#  '소바식당',
#  '성수동 우디집',
#  'Cheongdam-dong',
#  '제스티살룬 Zesty Saloon',
#  '성수동뚝도시장',
#  'Cafe.bot',
#  '에르아룸',
#  '뚝섬 미술관',
#  'Myosaㅣ묘사서울',
#  '천상가옥',
#  'Fe26.seoul',
#  '청담동 Cheongdam dong',
#  '바이산 대림창고점',
#  'B101workroom',
#  'Raw Coffee Stand',
#  '다로베darobe',
#  '카멜 커피',
#  '성수동어느건물',
#  'Hosting House',
#  '키메네상점',
#  'orer 오르에르',
#  '헤이그라운드 서울숲',
#  '아비뚜에_habitué',
#  '성수빈티지',
#  '오토데포',
#  '다르시',
#  '온화 성수점',
#  '쎈느 서울 성수',
#  '구욱희씨',
#  'FAVOR SEOUL',
#  '탐광',
#  'Carnaby Street',
#  '핑거팁스',
#  '건대입구역',
#  '앤드밀',
#  '무드랩 Moodlab',
#  '낙원테산도성수',
#  '뚝섬역',
#  'Hanoi102',
#  '누메로도스',
#  'Contempo',
#  'Seoul, South Korea',
#  '성수역 어딘가',
#  '목로다방',
#  'Daegu, South Korea',
#  '로스트 성수',
#  '마를리',
#  '레이더',
#  '뚝섬 어딘가',
#  '성수동 호호식당',
#  '센터커피 - Center Coffee',
#  '카페라잌유',
#  '원모어프로포즈 연남',
#  'Supyhaus',
#  'Super Matcha 슈퍼말차',
#  '성수역',
#  '성수명당',
#  '성수골목',
#  'Vacant Shop',
#  '데일리오아시스 샤로수길점',
#  '메쉬커피 Meshcoffee',
#  '뉴트로 성수',
#  '아르코커피',
#  '가비당성수',
#  '성수미술관',
#  'Bnhr 성수',
#  '고사포해수욕장',
#  '우동가조쿠',
#  'Bimbom',
#  'Ego By Showroom',
#  '멜로워 코리아 - Mellower Korea Co.,Ltd',
#  '건대 스타시티 준오헤어',
#  '유어네이키드치즈',
#  '오레노카츠',
#  '플디',
#  '커피 한 잔',
#  '포메이커-Formaker',
#  '건대 질서정연',
#  'Mammamia 도산',
#  'Eert',
#  'Kuna',
#  'Kusoy 쿠소이',
#  'Ndd',
#  '카페 글로우',
#  '오브코하우스',
#  'Humbolt',
#  '5to7',
#  'Busan, South Korea',
#  'Camouflage coffee',
#  '성수동 Baesan',
#  'Brewing Ceremony',
#  'Below Seongsoo',
#  '보이어 - boyer',
#  'Baesan',
#  '하루앤원데이 Haru & One Day',
#  '송정커피',
#  'Balance 발렁스',
#  'Scenery 시너리',
#  '린다비스타',
#  '현대백화점',
#  '성수동1가',
#  '레몬그라스 / lemongrass',
#  'Nontanto',
#  'Popina Seoul',
#  'Elephant seoul - 엘리펀트카페',
#  'Rsg_seongsu',
#  '기분꽃같네',
#  'Meganate',
#  'Peercoffee roasters 피어커피',
#  'Saisa',
#  '글루미커피',
#  '비에이치테이블',
#  '나인원 한남',
#  '봄의정원',
#  'Changwon, Korea',
#  '성수스타우트',
#  '중앙감속기',
#  '망원동티라미수 연남동점',
#  'Cafe_z0',
#  'K현대미술관',
#  'Cali.softserve_seoul',
#  'Titf',
#  '진해',
#  '잇샐러드',
#  'CAFE LOOOP 카페 루프',
#  '사진창고 Beantree',
#  '텐동식당',
#  '모므로살롱',
#  '레스빠스 성수점',
#  '힌스 아틀리에',
#  '송리단길 SongniDan-gil',
#  '피자시즌',
#  '술있는식탁',
#  '필무드',
#  '하남어딘가',
#  '코사이어티',
#  '에머이 성수점',
#  'Lowkey 성수점',
#  '식물관PH',
#  '바위파스타바',
#  '오브젝트 성수점',
#  '캘리소프트서브 서울숲점',
#  '피크닉 Piknic',
#  'Ppl',
#  '데어바타테',
#  'Goraebar',
#  '후식당 後食糖',
#  '달리아스파 건대점',
#  'Seongsu Station',
#  '이오커피로스터스',
#  '블리스바이미니',
#  '연희동 어딘가',
#  '카페앤아더',
#  'Mori, 途中 - 모리도중',
#  '토우드 갤러리',
#  'Coffeos (커피오스)',
#  '프릳츠 2호점',
#  '성수 레귤러',
#  '카페.오롯 Cafe.orot',
#  'Calice Italian caffè Bistrò 칼리체',
#  '폴라앳홈 스토어',
#  'Affiel Tower',
#  '인리치아이래쉬',
#  '오다주웠다,#odaju',
#  '크리커',
#  '매운향솥',
#  '뚝섬역4번출구',
#  '평이담백 뼈칼국수',
#  '뚝섬한강공원',
#  '티룸원더브루',
#  '육하나이',
#  'Marymond Lounge',
#  '외가집',
#  '펍포레스트',
#  '해남식당 성수동맛집',
#  '성수갈비골목',
#  '세스크멘슬',
#  'Momento Brewers',
#  'TEgg.42 - 테그42',
#  'Gunsan',
#  'À Côté du Parc',
#  '남원시립 김병종 미술관',
#  '하루나',
#  'Erolpa - 에롤파',
#  '디그루브',
#  'Changwon',
#  '최가커피',
#  'NICE Weather',
#  'Ezer Coffee',
#  '오거트',
#  'LE FREAK',
#  '성수동 빌런《villain》',
#  '오늘와인한잔',
#  '카페얀',
#  '상인동 롯데백화점',
#  'Minimize 미니마이즈',
#  'Wicker Park',
#  '모이핀',
#  'Cafe Cha',
#  '마켓온오프',
#  'Dorrell 6z4',
#  '연희동',
#  '선데이사운즈',
#  'Les601',
#  'Paperdollmate_Official',
#  'Damyang',
#  'Daejeon',
#  '여음',
#  'Veke',
#  '푸르너스 가든 서울숲점',
#  'BNHR 성수',
#  'Cafe라니',
#  '삼청동',
#  '영스데이',
#  '카페 심도 - Cafe Simdo',
#  'Cafe & Other',
#  '우정돈식당',
#  '롯데백화점본점',
#  'Mark69',
#  '양평',
#  '완전 행복한 내생일',
#  '스케줄청담',
#  '카페 소소하게',
#  '성수동 안씨네쭈꾸미',
#  '화정다방',
#  '명동',
#  '윤경 倫敬 성수동',
#  '우리집내방',
#  '빙봉',
#  'Gwangju',
#  '신두리해안사구',
#  '현명한 소비의 시작, 오브젝트',
#  '블루보틀 삼청 Bluebottle Samcheong',
#  '포맨스',
#  'Erou 이로우',
#  '오키로북스 파크',
#  '애월 어딘가',
#  '삼청동길 Samcheongdong Gil',
#  '상하목장',
#  'Matchacha Seoul',
#  'Fault Burger',
#  'スターバックス太宰府天満宮表参道店',
#  '성수동카페거리',
#  '온량',
#  'Cheonan, Korea',
#  'cumulus',
#  '홍화돈',
#  'Ulsan, Korea',
#  'Hotel Poco',
#  '헤이보울',
#  '성수 길거리 어딘가',
#  '블랙몬스터',
#  'Cafe Un.forget',
#  '유니코니 디저트카페',
#  'Cafe Loop',
#  'New York, New York',
#  '배불러 배불러',
#  'ARBY 알비',
#  'MOG',
#  'Spinning Wolf - Seongsu',
#  '성수 카페조이',
#  '카페바이민',
#  '매드만조',
#  '다포케',
#  '바스버거 성수점',
#  'Concept store SUPY',
#  '에딧숍 #editshop',
#  'Coffee Interview 커피인터뷰',
#  '신안군 퍼플교',
#  '거의끝집',
#  '밤가시마을',
#  '서울숲 언저리',
#  '서울숲 캘리소프트서브',
#  '서울 건대입구',
#  '카페 여주',
#  '토라식당',
#  '비포블루밍beforeblooming',
#  '행복한 주말',
#  '서울숲 오후',
#  '상왕십리역',
#  '건대역 근처 어딘가',
#  'Cafe Scene',
#  '성수 봄의정원',
#  'Immute',
#  '굿갓',
#  '프라이데이 무브먼트',
#  '빵의 정석',
#  '올드나이브스 성수',
#  '한남동',
#  '더 파크뷰 (The Parkview)',
#  '크롭커피',
#  '성수동2가 289-230 타로스토리',
#  '루디먼트 rudiment',
#  '화랑의언덕',
#  '성수동 타이거풀',
#  '서촌마을 골목',
#  '본노엘',
#  '압구정 Apgujeong',
#  '칼퇴근길',
#  'Chikachikashop',
#  '성수부두ㅡ뱃놈시즌3',
#  '연남동 어딘가',
#  '카페라니_cafe rani',
#  '동대문디자인플라자 DDP',
#  'Affair Coffee 어페어 커피',
#  '랑데자뷰 건대']

# %% [markdown]
# ### 카카오 지도 API를 활용한 장소 검색

# %%
#카카오 검색 API
import requests
searching = '성수동' # 검색할 키워드
url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)

headers = {
    #카카오API키입력
    "Authorization": "KakaoAK c365fabe892788f00e612734bd99c75f"
    # 입력시 반드시  KakaoAK 뒤에 한 칸 띄우고 API키 값을 적어야 합니다. 
}
places = requests.get(url, headers = headers).json()['documents']
places
# Out:
# [{'address_name': '서울 성동구 성수동1가 685-696',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 테마파크',
#   'distance': '',
#   'id': '1683241129',
#   'phone': '02-2261-1393',
#   'place_name': '브릭캠퍼스 서울',
#   'place_url': 'http://place.map.kakao.com/1683241129',
#   'road_address_name': '서울 성동구 서울숲2길 32-14',
#   'x': '127.04290967796628',
#   'y': '37.545577319610814'},
#  {'address_name': '서울 성동구 성수동1가 685-20',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '여행 > 관광,명소 > 관광안내소',
#   'distance': '',
#   'id': '18059737',
#   'phone': '',
#   'place_name': '서울숲 방문자센터',
#   'place_url': 'http://place.map.kakao.com/18059737',
#   'road_address_name': '서울 성동구 뚝섬로 273',
#   'x': '127.041690655005',
#   'y': '37.5429945913268'},
#  {'address_name': '서울 성동구 성수동1가 668-11',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 테마거리 > 먹자골목',
#   'distance': '',
#   'id': '21766257',
#   'phone': '',
#   'place_name': '성수동갈비골목',
#   'place_url': 'http://place.map.kakao.com/21766257',
#   'road_address_name': '',
#   'x': '127.044168799464',
#   'y': '37.5469328588197'},
#  {'address_name': '서울 성동구 성수동1가 668-11',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 테마거리 > 카페거리',
#   'distance': '',
#   'id': '1780698606',
#   'phone': '',
#   'place_name': '서울숲카페거리',
#   'place_url': 'http://place.map.kakao.com/1780698606',
#   'road_address_name': '',
#   'x': '127.043028992489',
#   'y': '37.5464440372535'},
#  {'address_name': '서울 성동구 성수동1가 685-715',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 수목원,식물원',
#   'distance': '',
#   'id': '13127878',
#   'phone': '',
#   'place_name': '서울숲 곤충식물원',
#   'place_url': 'http://place.map.kakao.com/13127878',
#   'road_address_name': '',
#   'x': '127.039209487238',
#   'y': '37.5414277019142'},
#  {'address_name': '서울 성동구 성수동1가 685-571',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '여행 > 관광,명소 > 문화유적 > 탑,비석',
#   'distance': '',
#   'id': '23394952',
#   'phone': '',
#   'place_name': '성수대교참사 희생자위령탑',
#   'place_url': 'http://place.map.kakao.com/23394952',
#   'road_address_name': '',
#   'x': '127.039321736561',
#   'y': '37.539708556845'},
#  {'address_name': '서울 성동구 성수동1가 685-20',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 테마거리',
#   'distance': '',
#   'id': '946487614',
#   'phone': '',
#   'place_name': '서울숲 은행나무길',
#   'place_url': 'http://place.map.kakao.com/946487614',
#   'road_address_name': '서울 성동구 뚝섬로 273',
#   'x': '127.041881891663',
#   'y': '37.5450271781489'},
#  {'address_name': '서울 성동구 성수동1가',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 테마거리',
#   'distance': '',
#   'id': '27481535',
#   'phone': '',
#   'place_name': '아틀리에길',
#   'place_url': 'http://place.map.kakao.com/27481535',
#   'road_address_name': '',
#   'x': '127.04090536026',
#   'y': '37.5471322541742'},
#  {'address_name': '서울 성동구 성수동1가 645-2',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '여행 > 관광,명소 > 연못',
#   'distance': '',
#   'id': '18059744',
#   'phone': '',
#   'place_name': '서울숲 거울연못',
#   'place_url': 'http://place.map.kakao.com/18059744',
#   'road_address_name': '',
#   'x': '127.040994304081',
#   'y': '37.544238214288'},
#  {'address_name': '서울 성동구 성수동1가 699-2',
#   'category_group_code': '',
#   'category_group_name': '',
#   'category_name': '여행 > 관광,명소 > 생태보존,서식지',
#   'distance': '',
#   'id': '17560306',
#   'phone': '',
#   'place_name': '서울숲 생태숲',
#   'place_url': 'http://place.map.kakao.com/17560306',
#   'road_address_name': '',
#   'x': '127.032054483175',
#   'y': '37.5431525721531'},
#  {'address_name': '서울 성동구 성수동1가',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 도보여행',
#   'distance': '',
#   'id': '26563608',
#   'phone': '',
#   'place_name': '서울숲공원산책길',
#   'place_url': 'http://place.map.kakao.com/26563608',
#   'road_address_name': '',
#   'x': '127.03874522144',
#   'y': '37.5451399728993'},
#  {'address_name': '서울 성동구 성수동1가 678-4',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 숲',
#   'distance': '',
#   'id': '17563475',
#   'phone': '',
#   'place_name': '서울숲 숲속길',
#   'place_url': 'http://place.map.kakao.com/17563475',
#   'road_address_name': '',
#   'x': '127.037093252208',
#   'y': '37.5454108031282'},
#  {'address_name': '서울 성동구 성수동1가 676-1',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 수목원,식물원',
#   'distance': '',
#   'id': '27587169',
#   'phone': '',
#   'place_name': '뚝섬유수지체육공원 정수식물원',
#   'place_url': 'http://place.map.kakao.com/27587169',
#   'road_address_name': '서울 성동구 서울숲길 25',
#   'x': '127.040404008064',
#   'y': '37.5491362479083'},
#  {'address_name': '서울 성동구 성수동1가',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 도보여행 > 둘레길',
#   'distance': '',
#   'id': '13032059',
#   'phone': '',
#   'place_name': '성동올레길',
#   'place_url': 'http://place.map.kakao.com/13032059',
#   'road_address_name': '',
#   'x': '127.037414010798',
#   'y': '37.5441889469854'},
#  {'address_name': '서울 성동구 성수동1가',
#   'category_group_code': 'AT4',
#   'category_group_name': '관광명소',
#   'category_name': '여행 > 관광,명소 > 저수지',
#   'distance': '',
#   'id': '10665148',
#   'phone': '',
#   'place_name': '뚝섬유수지',
#   'place_url': 'http://place.map.kakao.com/10665148',
#   'road_address_name': '',
#   'x': '127.040236707765',
#   'y': '37.5494750804823'}]

# %%
# 장소 검색 함수 만들기
def find_places(searching):
    # ① 접속URL 만들기
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json?query={}'.format(searching)
    # ② headers 입력하기
    headers = {
    #카카오API키입력
    "Authorization": "KakaoAK c365fabe892788f00e612734bd99c75f" 
    # 입력시 반드시  KakaoAK 뒤에 한 칸 띄우고 API키 값을 적어야 합니다. 
    }
    # ③ API 요청&정보 받기
    places = requests.get(url, headers = headers).json()['documents']
    # ④ 필요한 정보 선택하기
    place = places[0] 
    name = place['place_name']
    x=place['x']
    y=place['y']
    data = [name, x, y, searching] 

    return data

# %%
from tqdm import tqdm_notebook

# %%
# 인스타그램 위치명 위치정보 검색하기
#### 검색시 시간이 많이 걸려, 현재 작업 진행현황을 볼 수 있도록,  tqdm_notebook 추가 했습니다.
import time
locations_inform = [ ]
for location in tqdm_notebook(locations):
    try:
        data = find_places(location)       
        locations_inform.append(data) 
        time.sleep(0.5) 
    except:
        pass
locations_inform
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=346.0), HTML(value='')))
# [['브릭캠퍼스 서울', '127.04290967796628', '37.545577319610814', '성수동'],
#  ['아르코커피', '127.053429525035', '37.5448882689356', 'Arco  아르코'],
#  ['할아버지공장', '127.054835558322', '37.5410980207173', '할아버지공장'],
#  ['페이스뮤직', '126.915848984951', '37.5512791744838', 'Seoul, Korea'],
#  ['서울숲', '127.037617759165', '37.5443222301513', '서울숲 Seoul Forest Park'],
#  ['루프탑카페 연무장', '127.053309270784', '37.542867381825', '연무장'],
#  ['성수2가 1동주민센터', '127.054035594083', '37.5395549767301', '성수동 성수2가'],
#  ['옹근달', '127.05299006599826', '37.54271255358584', '옹근달'],
#  ['헤이보울', '127.05508248800928', '37.541450196679186', '헤이보울 hey.bowl'],
#  ['칸토', '127.051530874739', '37.5434339989228', 'KANTO CAFE'],
#  ['블루보틀 성수',
#   '127.04564285335792',
#   '37.548088279686716',
#   '블루보틀 Blue Bottle 성수'],
#  ['신사복 창고매장', '126.903139430223', '37.4907184552829', '대림 창고'],
#  ['서울숲카페거리', '127.043028992489', '37.5464440372535', '성수동 카페거리'],
#  ['브릭캠퍼스 서울', '127.04290967796628', '37.545577319610814', '성수'],
#  ['성수연방', '127.05695851079544', '37.54139704871741', '성수연방'],
#  ['공간와디즈', '127.05052480325075', '37.544930092473344', '공간 와디즈'],
#  ['우란문화재단', '127.05428078521324', '37.54376433464276', '우란문화재단'],
#  ['빅토리아베이커리', '127.040629148252', '37.5469485457655', '빅토리아 베이커리'],
#  ['세라 성수직영점', '127.056310217354', '37.5429921288565', '세라성수점'],
#  ['김봉남포장마차 가로수길근처점', '127.024859040201', '37.519497615662', '성수동근처'],
#  ['어니언', '127.05821260799398', '37.54478599695387', 'Cafe Onion'],
#  ['카페포제', '127.05575119265147', '37.54293653214302', '카페 포제 - cafe poze'],
#  ['Bnhr coffee', '127.001457317516', '37.5371958978897', 'BNHR'],
#  ['서울숲', '127.037617759165', '37.5443222301513', '서울숲'],
#  ['비비해이', '127.0609322922396', '37.541249103192726', 'BBHAY'],
#  ['어반소스', '127.051332566783', '37.5446666523304', '성수동 어반소스'],
#  ['메가박스 성수', '127.04490810531418', '37.541886984099314', '메가박스 성수'],
#  ['ㅊa', '127.124827032723', '37.3856383710853', 'ㅊa'],
#  ['이태리차차', '127.051055679631', '37.5435170972785', '이태리차차'],
#  ['어니언', '127.05821260799398', '37.54478599695387', '성수동 어니언'],
#  ['성수다락', '127.056230968905', '37.5399251637352', '성수다락'],
#  ['커피사피엔스 성수현대테라스점', '127.053805668779', '37.5439555639408', '커피사피엔스 성수점'],
#  ['시몬스 하드웨어 스토어', '127.446272733685', '37.197717225677', '시몬스 하드웨어 스토어'],
#  ['유어네임히얼', '127.040022689001', '37.5471001206878', '유어네임히얼'],
#  ['아모레성수', '127.059040730967', '37.5445477220243', '아모레성수'],
#  ['소바식당 성수점', '127.0550044286049', '37.543011665300575', '소바식당'],
#  ['우디집', '127.05099291898384', '37.53776153756109', '성수동 우디집'],
#  ['제스티살룬', '127.04085558526258', '37.54716110336998', '제스티살룬 Zesty Saloon'],
#  ['뚝도시장', '127.054338052181', '37.5384772418798', '성수동뚝도시장'],
#  ['카페봇', '127.058298554128', '37.544717478617', 'Cafe.bot'],
#  ['에르아룸', '127.049970163529', '37.544678048714', '에르아룸'],
#  ['마이아트뮤지엄', '127.060581455539', '37.5075914432752', '뚝섬 미술관'],
#  ['천상가옥', '127.056906467695', '37.5414060838052', '천상가옥'],
#  ['청담동명품거리', '127.046048046817', '37.5261262382238', '청담동 Cheongdam dong'],
#  ['로우커피스탠드', '127.04663357436208', '37.54715716085294', 'Raw Coffee Stand'],
#  ['다로베 서울숲점', '127.042711798688', '37.5478199776599', '다로베darobe'],
#  ['카멜커피 청담점', '127.0484288939293', '37.527073140027476', '카멜 커피'],
#  ['호스팅하우스', '127.05492717342', '37.5395041093963', 'Hosting House'],
#  ['키메네상점', '127.068109110495', '37.5457790104378', '키메네상점'],
#  ['오르에르', '127.051377043091', '37.5435205618933', 'orer 오르에르'],
#  ['헤이그라운드 서울숲점', '127.044177308783', '37.5479293603116', '헤이그라운드 서울숲'],
#  ['성수빈티지', '127.043267571492', '37.5461186894426', '성수빈티지'],
#  ['오토데포', '127.048942700007', '37.5446820830368', '오토데포'],
#  ['다르시', '127.052883905212', '37.5494088256076', '다르시'],
#  ['온화 성수점', '127.05260942869523', '37.54530760175276', '온화 성수점'],
#  ['쎈느', '127.053446501853', '37.5448927662487', '쎈느 서울 성수'],
#  ['구욱희씨', '127.041869477814', '37.5471102922797', '구욱희씨'],
#  ['탐광', '127.055411902856', '37.5431709516945', '탐광'],
#  ['핑거팁스', '127.055110893987', '37.5431476665748', '핑거팁스'],
#  ['건대입구역 2호선', '127.069202917341', '37.5404084182632', '건대입구역'],
#  ['앤드밀', '127.046934375299', '37.5468272760925', '앤드밀'],
#  ['낙원테산도 성수점', '127.043355370975', '37.547270133855', '낙원테산도성수'],
#  ['뚝섬역 2호선', '127.04738727881', '37.547241554679', '뚝섬역'],
#  ['하노이102', '127.043553472904', '37.5473907947945', 'Hanoi102'],
#  ['누메로도스', '127.04736069202619', '37.546356784437194', '누메로도스'],
#  ['CONTEMPO빌딩', '127.020624641356', '37.5223239761109', 'Contempo'],
#  ['목로다방', '127.0567332394995', '37.53977355551328', '목로다방'],
#  ['로스트 성수점', '127.055794286665', '37.5430644537097', '로스트 성수'],
#  ['마를리', '127.054745135469', '37.5427802289338', '마를리'],
#  ['레이더', '127.05402042061', '37.5436166901471', '레이더'],
#  ['어디고 서울지사', '127.056821824842', '37.5073914865238', '뚝섬 어딘가'],
#  ['호호식당 성수동점', '127.04391542788', '37.5471167570907', '성수동 호호식당'],
#  ['센터커피 명동점', '126.986924592233', '37.5647260878514', '센터커피 - Center Coffee'],
#  ['카페라잌유', '127.04717376638', '37.5460198856423', '카페라잌유'],
#  ['원모어프로포즈', '126.925545428217', '37.5646348592964', '원모어프로포즈 연남'],
#  ['슈퍼말차 성수', '127.043722153527', '37.5475114662965', 'Super Matcha 슈퍼말차'],
#  ['성수역 2호선', '127.056066999327', '37.5445888153751', '성수역'],
#  ['성수명당', '127.062713160133', '37.5410787829105', '성수명당'],
#  ['성수골목', '127.043474671705', '37.5461510493398', '성수골목'],
#  ['베이컨트샵', '126.903834444885', '37.5588924384838', 'Vacant Shop'],
#  ['데일리오아시스 샤로수길점', '126.956590757608', '37.4781468803909', '데일리오아시스 샤로수길점'],
#  ['메쉬커피', '127.042453959446', '37.5481192022199', '메쉬커피 Meshcoffee'],
#  ['뉴트로성수', '127.056429917064', '37.5396655808552', '뉴트로 성수'],
#  ['아르코커피', '127.053429525035', '37.5448882689356', '아르코커피'],
#  ['가비당', '127.049815772829', '37.5507328254881', '가비당성수'],
#  ['성수미술관', '127.054795978487', '37.5457679188565', '성수미술관'],
#  ['BNHR 성수점', '127.052651814064', '37.5444336136718', 'Bnhr 성수'],
#  ['고사포해수욕장', '126.50431776785', '35.6595885878744', '고사포해수욕장'],
#  ['우동가조쿠', '127.042884423889', '37.5568010637512', '우동가조쿠'],
#  ['빙봉 이태원점', '126.992274100843', '37.5401617468437', 'Bimbom'],
#  ['준오헤어 건대역1호점', '127.07115901956539', '37.54012253980543', '건대 스타시티 준오헤어'],
#  ['유어네이키드치즈', '127.04761583226055', '37.54185438832984', '유어네이키드치즈'],
#  ['오레노카츠', '127.049517573532', '37.5447359033199', '오레노카츠'],
#  ['플디', '127.048519334096', '37.5479294580028', '플디'],
#  ['커피한잔', '126.9679400412981', '37.57706609381111', '커피 한 잔'],
#  ['질서정연', '127.06779784392', '37.5431915199805', '건대 질서정연'],
#  ['EERT', '127.04099944900322', '37.54743405615237', 'Eert'],
#  ['쿠나', '127.052742314001', '37.5443975333154', 'Kuna'],
#  ['앤디디', '127.041168056734', '37.547429492495', 'Ndd'],
#  ['카페글로우', '126.678012520818', '37.4194018466714', '카페 글로우'],
#  ['훔볼트', '127.055597468953', '37.5401128716699', 'Humbolt'],
#  ['5TO7', '127.043321867062', '37.5460826295749', '5to7'],
#  ['바이산', '127.056313862538', '37.541820827733', '성수동 Baesan'],
#  ['바이산', '127.056313862538', '37.541820827733', 'Baesan'],
#  ['하루앤원데이', '127.054283845345', '37.544863552313', '하루앤원데이 Haru & One Day'],
#  ['송정커피', '127.067136112681', '37.552273964594', '송정커피'],
#  ['시너리', '127.045140497226', '37.5444745659109', 'Scenery 시너리'],
#  ['린다비스타', '127.06196484910984', '37.53925375225815', '린다비스타'],
#  ['현대백화점 무역센터점', '127.0598086324825', '37.50857933831633', '현대백화점'],
#  ['브릭캠퍼스 서울', '127.04290967796628', '37.545577319610814', '성수동1가'],
#  ['레몬그라스타이', '127.02132001742319', '37.48536100210304', '레몬그라스 / lemongrass'],
#  ['논탄토', '127.023886668047', '37.5209141930557', 'Nontanto'],
#  ['기분꽃같네', '127.072807905378', '37.5334361123819', '기분꽃같네'],
#  ['SAISA', '127.047587127052', '37.5483190687988', 'Saisa'],
#  ['비에이치테이블', '127.08078217024651', '37.53777374907963', '비에이치테이블'],
#  ['나인원', '126.99868758985', '37.5325863795484', '나인원 한남'],
#  ['봄의정원', '127.047482019442', '37.5413931303749', '봄의정원'],
#  ['한국이슬람교 창원성원', '128.674015728866', '35.2263142690358', 'Changwon, Korea'],
#  ['성수스타우트', '127.044345393817', '37.5470409124964', '성수스타우트'],
#  ['중앙감속기', '127.051084241076', '37.5455749671444', '중앙감속기'],
#  ['망원동티라미수 연남동점', '126.925066022734', '37.5596069959436', '망원동티라미수 연남동점'],
#  ['K현대미술관', '127.03913323759338', '37.524349883168405', 'K현대미술관'],
#  ['TITF', '128.692762521254', '35.9885003562431', 'Titf'],
#  ['여좌천', '128.660414261631', '35.1622297838177', '진해'],
#  ['잇샐러드', '127.05355242008956', '37.54584597529271', '잇샐러드'],
#  ['텐동요츠야', '126.954482892053', '37.478953391547', '텐동식당'],
#  ['모므로살롱', '127.043828995264', '37.5463815740955', '모므로살롱'],
#  ['레스빠스 성수점', '127.049138129674', '37.5459001526753', '레스빠스 성수점'],
#  ['피자시즌', '127.05690646495559', '37.541402479807836', '피자시즌'],
#  ['술있는식탁', '127.046377463688', '37.5465644044558', '술있는식탁'],
#  ['필무드', '126.912003129783', '37.7763125400684', '필무드'],
#  ['전국어디서나전국이사몰', '127.146415690833', '37.5421219048491', '하남어딘가'],
#  ['코사이어티', '127.045721222376', '37.5448527621598', '코사이어티'],
#  ['에머이 성수점', '127.05721509461205', '37.545483857798985', '에머이 성수점'],
#  ['식물관PH', '127.094331083333', '37.4826366596631', '식물관PH'],
#  ['바위파스타바', '127.061566457128', '37.539122414633', '바위파스타바'],
#  ['오브젝트 성수점', '127.04131766923071', '37.54786372164992', '오브젝트 성수점'],
#  ['캘리소프트서브', '127.0436072402', '37.5464465281219', '캘리소프트서브 서울숲점'],
#  ['피크닉', '126.97812314817759', '37.556958192580645', '피크닉 Piknic'],
#  ['ppl', '129.313608653694', '35.5395534474869', 'Ppl'],
#  ['데어바타테', '127.056750139664', '37.5426639544529', '데어바타테'],
#  ['달리아스파 건대점', '127.069491970625', '37.5397487166459', '달리아스파 건대점'],
#  ['성수역 2호선', '127.056066999327', '37.5445888153751', 'Seongsu Station'],
#  ['이오커피로스터스', '127.047804870446', '37.541968738907', '이오커피로스터스'],
#  ['블리스바이미니', '127.045600164031', '37.5486009644164', '블리스바이미니'],
#  ['어디가손세차장', '126.94203094468874', '37.55759470684954', '연희동 어딘가'],
#  ['앤아더', '127.042760733457', '37.5463206978435', '카페앤아더'],
#  ['레귤러', '127.05580667785524', '37.541471480649356', '성수 레귤러'],
#  ['카페오롯', '127.049569846913', '37.5484876408465', '카페.오롯 Cafe.orot'],
#  ['폴라앳홈', '127.052181169277', '37.5478053607514', '폴라앳홈 스토어'],
#  ['인리치아이래쉬 성수본점', '127.04748166256906', '37.53904602579363', '인리치아이래쉬'],
#  ['오다주웠다', '127.047006784304', '37.5468056233164', '오다주웠다,#odaju'],
#  ['크리커', '127.444635202367', '37.2825534526709', '크리커'],
#  ['매운향솥 본점', '127.06626440648117', '37.53914149590237', '매운향솥'],
#  ['뚝섬역 2호선 4번출구', '127.048984872684', '37.5468768992081', '뚝섬역4번출구'],
#  ['평이담백뼈칼국수', '126.913889940044', '37.554337550539', '평이담백 뼈칼국수'],
#  ['뚝섬한강공원', '127.06892112991', '37.5292974433415', '뚝섬한강공원'],
#  ['티룸원더브루', '127.04324142295', '37.5478666368327', '티룸원더브루'],
#  ['육하나이', '127.054679812396', '37.5478474780756', '육하나이'],
#  ['외가집', '127.05149148298543', '37.54374305888836', '외가집'],
#  ['펍포레스트', '127.051982919805', '37.5426048812973', '펍포레스트'],
#  ['해남식당', '127.048228606228', '37.5463257991784', '해남식당 성수동맛집'],
#  ['성수동갈비골목', '127.044168799464', '37.5469328588197', '성수갈비골목'],
#  ['세스크멘슬 본점', '127.056407186023', '37.5410333094744', '세스크멘슬'],
#  ['모멘토브루어스', '127.041185016539', '37.5474033576152', 'Momento Brewers'],
#  ['테그42 성수본점', '127.053672237789', '37.5440853685614', 'TEgg.42 - 테그42'],
#  ['라마다군산호텔', '126.689916868655', '35.9588468263945', 'Gunsan'],
#  ['남원시립김병종미술관', '127.38960334256944', '35.39867609059592', '남원시립 김병종 미술관'],
#  ['하루나', '127.05298512856578', '37.542131411099525', '하루나'],
#  ['에롤파', '127.049069604215', '37.5380326524747', 'Erolpa - 에롤파'],
#  ['창원역', '128.606553084154', '35.2575062903909', 'Changwon'],
#  ['최가커피', '127.07060842937145', '37.5430006629962', '최가커피'],
#  ['에젤커피', '127.057371850952', '37.546264046869', 'Ezer Coffee'],
#  ['오거트', '127.04945208737', '37.5483813723846', '오거트'],
#  ['빌런', '127.049160282698', '37.5382776868165', '성수동 빌런《villain》'],
#  ['오늘와인한잔', '127.1095492530017', '37.321149810832466', '오늘와인한잔'],
#  ['카페얀', '129.203939529128', '35.8557954231181', '카페얀'],
#  ['롯데백화점 상인점', '128.53890166350524', '35.81879043423177', '상인동 롯데백화점'],
#  ['위커파크', '127.10818467344016', '37.5115939365724', 'Wicker Park'],
#  ['모이핀', '127.77908990795547', '34.687856172688974', '모이핀'],
#  ['한옥카페차차', '126.651893214898', '36.8825847680154', 'Cafe Cha'],
#  ['마켓온오프 성수', '127.0434624240097', '37.54649523545645', '마켓온오프'],
#  ['인천둘레길 2코스', '126.708057970044', '37.547416348083', '연희동'],
#  ['선데이사운즈', '126.981550187644', '37.5474478415719', '선데이사운즈'],
#  ['담양IC', '126.979590105079', '35.2805628601953', 'Damyang'],
#  ['Daejeon제일공인중개사사무소', '127.3701816330705', '36.34671554341633', 'Daejeon'],
#  ['여음', '127.043281442315', '37.5466232437808', '여음'],
#  ['베케', '126.60492258733058', '33.26190881355424', 'Veke'],
#  ['푸르너스가든 서울숲점', '127.043629647394', '37.5460608922798', '푸르너스 가든 서울숲점'],
#  ['BNHR 성수점', '127.052651814064', '37.5444336136718', 'BNHR 성수'],
#  ['Cafe 연남동 223-14', '126.923878689842', '37.5652464736959', 'Cafe라니'],
#  ['삼청동거리', '126.981482777468', '37.5820641053666', '삼청동'],
#  ['영스데이', '127.054202561957', '37.5388737441929', '영스데이'],
#  ['레드브릿지', '126.9282191538652', '37.773858496820615', 'Cafe & Other'],
#  ['우정돈식당', '127.055929146035', '37.5418246145697', '우정돈식당'],
#  ['롯데백화점 본점', '126.981799354998', '37.5651867190291', '롯데백화점본점'],
#  ['세미원', '127.32421150228701', '37.54074767932927', '양평'],
#  ['청담스케쥴', '127.042703080533', '37.524596692327', '스케줄청담'],
#  ['카페소소하게', '127.04685725635449', '37.539323783220524', '카페 소소하게'],
#  ['안씨네쭈꾸미 성수점', '127.054204467523', '37.5477575973665', '성수동 안씨네쭈꾸미'],
#  ['화정다방', '126.832460453281', '37.6392963646861', '화정다방'],
#  ['명동거리', '126.984901336292', '37.5620769169639', '명동'],
#  ['우리집젤라또', '126.985670974847', '37.4911465276096', '우리집내방'],
#  ['서울숲빙봉', '127.04045823550858', '37.546873821540764', '빙봉'],
#  ['광주경찰서', '127.239583690907', '37.408267273136', 'Gwangju'],
#  ['신두리해안사구', '126.196450884174', '36.844612276151', '신두리해안사구'],
#  ['포맨스', '127.04338241159866', '37.547066498184584', '포맨스'],
#  ['오키로북스 파크', '127.042453959446', '37.5481192022199', '오키로북스 파크'],
#  ['어디든집', '126.391229669554', '33.4681743856374', '애월 어딘가'],
#  ['삼청동길', '126.981743337459', '37.5906452023744', '삼청동길 Samcheongdong Gil'],
#  ['상하목장', '126.451429013871', '35.4431619973327', '상하목장'],
#  ['성수동카페거리', '127.05639353022181', '37.54243256842165', '성수동카페거리'],
#  ['온량', '127.043440031512', '37.5469079011998', '온량'],
#  ['Cohu Korea Cheonan',
#   '127.111086906826',
#   '36.8238185239379',
#   'Cheonan, Korea'],
#  ['큐뮬러스', '127.05053684295356', '37.539297037859875', 'cumulus'],
#  ['홍화돈', '127.046350559703', '37.5469752705161', '홍화돈'],
#  ['울산한샘성결교회', '129.32357172724', '35.5345645468922', 'Ulsan, Korea'],
#  ['호텔포코 성수점', '127.057043804328', '37.5434458804588', 'Hotel Poco'],
#  ['헤이보울', '127.05508248800928', '37.541450196679186', '헤이보울'],
#  ['블랙몬스터', '127.031932965238', '37.512922192628', '블랙몬스터'],
#  ['유니코니', '127.12494601038155', '37.325964089235114', '유니코니 디저트카페'],
#  ['룹', '127.049186437287', '37.543644030586', 'Cafe Loop'],
#  ['뉴욕NY 홍대점', '126.922379235622', '37.5529667120306', 'New York, New York'],
#  ['배불러돈가스', '127.351611263913', '36.3072440976341', '배불러 배불러'],
#  ['알비', '127.0399063452899', '37.54749750055046', 'ARBY 알비'],
#  ['MOG', '127.05473303365602', '37.54325235825022', 'MOG'],
#  ['조이보드카페', '127.03871298279', '37.5265577473085', '성수 카페조이'],
#  ['카페바이민', '127.08375035701454', '37.39013375821705', '카페바이민'],
#  ['매드만조', '126.925643944099', '37.5611750955618', '매드만조'],
#  ['다포케', '127.05391133400417', '37.54298153542346', '다포케'],
#  ['바스버거 성수점', '127.046295736709', '37.5461571849968', '바스버거 성수점'],
#  ['커피인터뷰', '127.341306029317', '36.3645744829947', 'Coffee Interview 커피인터뷰'],
#  ['퍼플교', '126.121636094523', '34.7174534139804', '신안군 퍼플교'],
#  ['거의끝집', '127.055639711221', '37.5482326571023', '거의끝집'],
#  ['밤가시마을', '126.777804321309', '37.6743118910357', '밤가시마을'],
#  ['캘리소프트서브', '127.0436072402', '37.5464465281219', '서울숲 캘리소프트서브'],
#  ['건대입구역 2호선', '127.069202917341', '37.5404084182632', '서울 건대입구'],
#  ['카페여주', '127.71918058506138', '37.264377210136686', '카페 여주'],
#  ['토라식당', '127.049378097819', '37.5460081724542', '토라식당'],
#  ['오후', '127.043340032516', '37.5461862377943', '서울숲 오후'],
#  ['상왕십리역 2호선', '127.029274674797', '37.564438467635', '상왕십리역'],
#  ['카페씬', '129.064614083788', '35.1552496493778', 'Cafe Scene'],
#  ['봄의정원', '127.047482019442', '37.5413931303749', '성수 봄의정원'],
#  ['아임뮤트', '127.02514153552723', '37.52196810590861', 'Immute'],
#  ['굿갓 팬스테이크&파스타', '127.0486384288', '37.7377739842011', '굿갓'],
#  ['프라이데이무브먼트', '127.045034873904', '37.5494733479673', '프라이데이 무브먼트'],
#  ['빵의정석', '127.04359817587863', '37.54642670949195', '빵의 정석'],
#  ['올드나이브스', '127.043698279196', '37.5473222653849', '올드나이브스 성수'],
#  ['한남동부군당', '127.00466563557', '37.5292345694785', '한남동'],
#  ['서울신라호텔 더파크뷰',
#   '127.005174317802',
#   '37.5559077408633',
#   '더 파크뷰 (The Parkview)'],
#  ['크롭커피', '127.055435170484', '37.5409743037937', '크롭커피'],
#  ['타로스토리 성수점', '127.055070768309', '37.5470535164798', '성수동2가 289-230 타로스토리'],
#  ['화랑의언덕', '129.090348179621', '35.7703151227985', '화랑의언덕'],
#  ['타이거풀', '127.054919136534', '37.5408880489357', '성수동 타이거풀'],
#  ['카페골목숲', '126.98206668490285', '37.58321025921711', '서촌마을 골목'],
#  ['본노엘', '127.04800447816', '37.5497424775667', '본노엘'],
#  ['웍스아웃 서울압구정점', '127.03848214271389', '37.52644970250709', '압구정 Apgujeong'],
#  ['어디가손세차장', '126.94203094468874', '37.55759470684954', '연남동 어딘가'],
#  ['카페라니', '127.054174265043', '37.5435517477142', '카페라니_cafe rani'],
#  ['DDP패션몰', '127.012156747242', '37.5673174505789', '동대문디자인플라자 DDP'],
#  ['어페어커피', '127.055047310675', '37.5366965368612', 'Affair Coffee 어페어 커피'],
#  ['랑데자뷰 건대점', '127.069192441561', '37.541316632105', '랑데자뷰 건대']]

# %%
#위치정보 저장하기
locations_inform_df = pd.DataFrame(locations_inform)
locations_inform_df.columns = ['name_official','경도','위도','인스타위치명']
locations_inform_df.to_excel('./files/위도경도.xlsx', index=False) # 위도경도 정보 액셀파일로 저장

# %%
#인스타 게시량 및 위치정보 데이터 불러오기
location_counts_df = pd.read_excel('./files/성수추천count.xlsx', index_col = 0)
locations_inform_df = pd.read_excel('./files/위도경도.xlsx')

# %%
#위치 데이터 병합하기(join)
location_data = pd.merge(locations_inform_df, location_counts_df, 
                         how = 'inner', left_on = 'name_official', right_index=True)

# # place 로 정렬하기(내림차순)
# location_data=location_data.sort_values(by='place' ,ascending=False )
# location_data.head(20)
# Out:
#    name_official          경도         위도                 인스타위치명  place
# 2         할아버지공장  127.054836  37.541098                 할아버지공장     34
# 7            옹근달  127.052990  37.542713                    옹근달     18
# 14          성수연방  127.056959  37.541397                   성수연방     13
# 16        우란문화재단  127.054281  37.543764                 우란문화재단     10
# 4            서울숲  127.037618  37.544322  서울숲 Seoul Forest Park      8
# 23           서울숲  127.037618  37.544322                    서울숲      8
# 26       메가박스 성수  127.044908  37.541887                메가박스 성수      7
# 28         이태리차차  127.051056  37.543517                  이태리차차      7
# 30          성수다락  127.056231  37.539925                   성수다락      7
# 27            ㅊa  127.124827  37.385638                     ㅊa      7
# 33        유어네임히얼  127.040023  37.547100                 유어네임히얼      6
# 32  시몬스 하드웨어 스토어  127.446273  37.197717           시몬스 하드웨어 스토어      6
# 34         아모레성수  127.059041  37.544548                  아모레성수      6
# 40          에르아룸  127.049970  37.544678                   에르아룸      5
# 42          천상가옥  127.056906  37.541406                   천상가옥      5
# 51         성수빈티지  127.043268  37.546119                  성수빈티지      4
# 54        온화 성수점  127.052609  37.545308                 온화 성수점      4
# 56          구욱희씨  127.041869  37.547110                   구욱희씨      4
# 53           다르시  127.052884  37.549409                    다르시      4
# 52          오토데포  127.048943  37.544682                   오토데포      4

# %%
#동일한 name_official 가지는 데이터 --> 인스타 게시 횟수 합치기
location_data = location_data.pivot_table(index = ['name_official','경도','위도'], values = 'place', aggfunc='sum')
location_data=location_data.sort_values(by='place' ,ascending=False )
location_data.head(20)
# Out:
#                                     place
# name_official 경도         위도
# 할아버지공장        127.054836 37.541098     34
# 옹근달           127.052990 37.542713     18
# 서울숲           127.037618 37.544322     16
# 성수연방          127.056959 37.541397     13
# 우란문화재단        127.054281 37.543764     10
# ㅊa            127.124827 37.385638      7
# 이태리차차         127.051056 37.543517      7
# 성수다락          127.056231 37.539925      7
# 메가박스 성수       127.044908 37.541887      7
# 유어네임히얼        127.040023 37.547100      6
# 시몬스 하드웨어 스토어  127.446273 37.197717      6
# 아모레성수         127.059041 37.544548      6
# 천상가옥          127.056906 37.541406      5
# 에르아룸          127.049970 37.544678      5
# 구욱희씨          127.041869 37.547110      4
# 오토데포          127.048943 37.544682      4
# 성수빈티지         127.043268 37.546119      4
# 키메네상점         127.068109 37.545779      4
# 아르코커피         127.053430 37.544888      4
# 다르시           127.052884 37.549409      4

# %%
#병합한 데이터 저장하기
location_data.to_excel('./files/성수result.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dc9acafeb036> in <module>
#       1 #병합한 데이터 저장하기
# ----> 2 location_data.to_excel('./files/성수result.xlsx')
#
# NameError: name 'location_data' is not defined

# %% [markdown]
# ### folium을 이용한 지도 시각화 ① - 개별 표시

# %%
#데이터 불러오기
location_data = pd.read_excel('./files/성수result.xlsx')
location_data.head()
# Out:
#   name_official          경도         위도  place
# 0        할아버지공장  127.054836  37.541098     34
# 1           옹근달  127.052990  37.542713     18
# 2           서울숲  127.037618  37.544322     16
# 3          성수연방  127.056959  37.541397     13
# 4        우란문화재단  127.054281  37.543764     10

# %%
#지도 표시하기
import folium

# 처음 나타나는 위도 경도 설정
sungsu =[37.541098, 127.054836]
map_sungsu = folium.Map(location = sungsu, zoom_start = 11)

for i in range(len(location_data)):
    name = location_data ['name_official'][i]    # 공식명칭
    count = location_data ['place'][i]           # 게시글 개수
    size = int(count)*2
    long = float(location_data['위도'][i])      
    lat = float(location_data['경도'][i])       
    folium.CircleMarker((long,lat), radius = size, color='red', popup=name).add_to(map_sungsu)
    
map_sungsu
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지도 저장하기
map_sungsu.save('./files/성수지도.html')

# %% [markdown]
# ### folium을 이용한 지도 시각화 ② - 그룹으로 표시

# %%
# 지도 표시하기(마커 집합)
from folium.plugins import MarkerCluster
from matplotlib import font_manager, rc
# 한글 폰트 설정
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

locations = []
names = []
for i in range(len(location_data)):
    data = location_data.iloc[i]  # 행 하나씩
    locations.append((float(data['위도']),float(data['경도'])))    # 위도 , 경도 순으로..
    names.append(data['name_official'])

icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(30, 30)
    });
}"""
# 처음 나타나는 위도 경도 설정
sungsu =[37.541098, 127.054836]
map_sungsu2 = folium.Map(location = sungsu, zoom_start = 11)
                       
marker_cluster = MarkerCluster(
    locations=locations, popups=names,
    name='성수',
    overlay=True,
    control=True,
    icon_create_function=icon_create_function
)

marker_cluster.add_to(map_sungsu2)
folium.LayerControl().add_to(map_sungsu2)

map_sungsu2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지도 저장하기
map_sungsu2.save('./files/성수지도2.html')
